# %% [markdown]
# <a href="https://colab.research.google.com/github/msakarvadia/memory_injections/blob/main/Memory_Injection_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Memory Injections: Correcting Multi-Hop Reasoning Failures during Inference in Transformer-Based Language Models
#
# ### By: Mansi Sakarvadia, Aswathy Ajith, Arham Khan, Daniel Grzenda, Nathaniel Hudson, André Bauer, Kyle Chard, Ian Foster
# **Paper link:** https://arxiv.org/abs/2309.05605
#
# **Paper abstract:**
# Answering multi-hop reasoning questions requires retrieving and synthesizing information from diverse sources. Large Language Models (LLMs) struggle to perform such reasoning consistently. Here we propose an approach to pinpoint and rectify multi-hop reasoning failures through targeted memory injections on LLM attention heads. First, we analyze the per-layer activations of GPT-2 models in response to single and multi-hop prompts. We then propose a mechanism that allows users to inject pertinent prompt-specific information, which we refer to as "memories," at critical LLM locations during inference. By thus enabling the LLM to incorporate additional relevant information during inference, we enhance the quality of multi-hop prompt completions. We show empirically that a simple, efficient, and targeted memory injection into a key attention layer can often increase the probability of the desired next token in multi-hop tasks, by up to 424%.
#
# **Notebook motivation:** This notebook is mean to accompany the experimental code to allow for users to interactively play with various prompts and our proposed memory injection technique live.

# %% [markdown]
# # Set up
#
# Import relavent libraries.

# %%
DEVELOPMENT_MODE = False
try:
    import google.colab
    IN_COLAB = True
    print("Running as a Colab notebook")
    # %pip install git+https://github.com/neelnanda-io/TransformerLens.git
    #%pip install circuitsvis

except:
    IN_COLAB = False
    print("Running as a Jupyter notebook - intended for development only!")
    from IPython import get_ipython

    ipython = get_ipython()
    # Code to automatically update the HookedTransformer code as its edited without restarting the kernel
    ipython.magic("load_ext autoreload")
    ipython.magic("autoreload 2")


# Import stuff
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd
import einops
from fancy_einsum import einsum
import tqdm.auto as tqdm
import random
from pathlib import Path
import plotly.express as px
from torch.utils.data import DataLoader

from jaxtyping import Float, Int
from typing import List, Union, Optional
from functools import partial
import copy

import itertools
from transformers import AutoModelForCausalLM, AutoConfig, AutoTokenizer
import dataclasses
import datasets
from IPython.display import HTML

import transformer_lens
import transformer_lens.utils as utils
from transformer_lens.hook_points import (
    HookedRootModule,
    HookPoint,
)  # Hooking utilities
from transformer_lens import HookedTransformer, HookedTransformerConfig, FactoredMatrix, ActivationCache
import matplotlib.pyplot as plt

import io
import requests

torch.set_grad_enabled(False)
device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# Running as a Colab notebook
# Collecting git+https://github.com/neelnanda-io/TransformerLens.git
#   Cloning https://github.com/neelnanda-io/TransformerLens.git to /tmp/pip-req-build-7t0o7_0y
#   Running command git clone --filter=blob:none --quiet https://github.com/neelnanda-io/TransformerLens.git /tmp/pip-req-build-7t0o7_0y
#   Resolved https://github.com/neelnanda-io/TransformerLens.git to commit 20a44fe3a8022d353c9cc7c984a8fcab14552d1c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting beartype<0.15.0,>=0.14.1 (from transformer-lens==0.0.0)
#   Downloading beartype-0.14.1-py3-none-any.whl (739 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.7/739.7 kB 3.6 MB/s eta 0:00:00
# Collecting datasets>=2.7.1 (from transformer-lens==0.0.0)
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 9.4 MB/s eta 0:00:00
# Collecting einops>=0.6.0 (from transformer-lens==0.0.0)
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.7 MB/s eta 0:00:00
# Collecting fancy-einsum>=0.0.3 (from transformer-lens==0.0.0)
#   Downloading fancy_einsum-0.0.3-py3-none-any.whl (6.2 kB)
# Collecting jaxtyping>=0.2.11 (from transformer-lens==0.0.0)
#   Downloading jaxtyping-0.2.21-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from transformer-lens==0.0.0) (1.23.5)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from transformer-lens==0.0.0) (1.5.3)
# Requirement already satisfied: rich>=12.6.0 in /usr/local/lib/python3.10/dist-packages (from transformer-lens==0.0.0) (13.5.2)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.10/dist-packages (from transformer-lens==0.0.0) (2.0.1+cu118)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from transformer-lens==0.0.0) (4.66.1)
# Collecting transformers>=4.25.1 (from transformer-lens==0.0.0)
#   Downloading transformers-4.33.1-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 24.3 MB/s eta 0:00:00
# Collecting wandb>=0.13.5 (from transformer-lens==0.0.0)
#   Downloading wandb-0.15.10-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 33.8 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.7.1->transformer-lens==0.0.0) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets>=2.7.1->transformer-lens==0.0.0)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.7.1->transformer-lens==0.0.0) (2.31.0)
# Collecting xxhash (from datasets>=2.7.1->transformer-lens==0.0.0)
#   Downloading xxhash-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 22.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets>=2.7.1->transformer-lens==0.0.0)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.7.1->transformer-lens==0.0.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.7.1->transformer-lens==0.0.0) (3.8.5)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets>=2.7.1->transformer-lens==0.0.0)
#   Downloading huggingface_hub-0.17.1-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 27.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets>=2.7.1->transformer-lens==0.0.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.7.1->transformer-lens==0.0.0) (6.0.1)
# Collecting typeguard>=2.13.3 (from jaxtyping>=0.2.11->transformer-lens==0.0.0)
#   Downloading typeguard-4.1.5-py3-none-any.whl (34 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.10/dist-packages (from jaxtyping>=0.2.11->transformer-lens==0.0.0) (4.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->transformer-lens==0.0.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->transformer-lens==0.0.0) (2023.3.post1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.6.0->transformer-lens==0.0.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.6.0->transformer-lens==0.0.0) (2.16.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->transformer-lens==0.0.0) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->transformer-lens==0.0.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->transformer-lens==0.0.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->transformer-lens==0.0.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->transformer-lens==0.0.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10->transformer-lens==0.0.0) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10->transformer-lens==0.0.0) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->transformer-lens==0.0.0) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers>=4.25.1->transformer-lens==0.0.0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 54.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers>=4.25.1->transformer-lens==0.0.0)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.4 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.13.5->transformer-lens==0.0.0) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading GitPython-3.1.36-py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.5/189.5 kB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.13.5->transformer-lens==0.0.0) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading sentry_sdk-1.31.0-py2.py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 23.2 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb>=0.13.5->transformer-lens==0.0.0) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.13.5->transformer-lens==0.0.0) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.13.5->transformer-lens==0.0.0) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb>=0.13.5->transformer-lens==0.0.0) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.7.1->transformer-lens==0.0.0) (1.3.1)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer-lens==0.0.0) (0.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.7.1->transformer-lens==0.0.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.7.1->transformer-lens==0.0.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.7.1->transformer-lens==0.0.0) (2023.7.22)
# Collecting typing-extensions>=3.7.4.1 (from jaxtyping>=0.2.11->transformer-lens==0.0.0)
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10->transformer-lens==0.0.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10->transformer-lens==0.0.0) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens==0.0.0)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: transformer-lens, pathtools
#   Building wheel for transformer-lens (pyproject.toml) ... done
#   Created wheel for transformer-lens: filename=transformer_lens-0.0.0-py3-none-any.whl size=110211 sha256=d5eb5e47b03a2b08fefe3cf8a41022800764f1a1666ae439e3f5f2473a6e3306
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2484j_ki/wheels/8a/1e/37/ffb9c15454a1725b13a9d9f5e74fb91725048884ad734b8c1f
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=943c55829f67e813659dad23148b0c426c193c1f01754e1c4750a51b7d6e7baa
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built transformer-lens pathtools
# Installing collected packages: tokenizers, safetensors, pathtools, xxhash, typing-extensions, smmap, setproctitle, sentry-sdk, fancy-einsum, einops, docker-pycreds, dill, beartype, typeguard, multiprocess, huggingface-hub, gitdb, transformers, jaxtyping, GitPython, wandb, datasets, transformer-lens
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.7.1 which is incompatible.
# Successfully installed GitPython-3.1.36 beartype-0.14.1 datasets-2.14.5 dill-0.3.7 docker-pycreds-0.4.0 einops-0.6.1 fancy-einsum-0.0.3 gitdb-4.0.10 huggingface-hub-0.17.1 jaxtyping-0.2.21 multiprocess-0.70.15 pathtools-0.1.2 safetensors-0.3.3 sentry-sdk-1.31.0 setproctitle-1.3.2 smmap-5.0.0 tokenizers-0.13.3 transformer-lens-0.0.0 transformers-4.33.1 typeguard-4.1.5 typing-extensions-4.7.1 wandb-0.15.10 xxhash-3.3.0

# %% [markdown]
# # Get Models
#
# Instantiate Models of interest. Here we use both gpt2_small and gpt2_large. You can use any model currently supported by the Transformer Lens library.

# %%
gpt2_small = HookedTransformer.from_pretrained("gpt2-small", device=device)
gpt2_small.cfg.use_attn_result = True
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Using pad_token, but it is not set yet.
# Loaded pretrained model gpt2-small into HookedTransformer

# %%
gpt2_large = HookedTransformer.from_pretrained("gpt2-large", device=device)
gpt2_large.cfg.use_attn_result = True
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Using pad_token, but it is not set yet.
# Loaded pretrained model gpt2-large into HookedTransformer

# %%
for name, param in gpt2_small.named_parameters():
  print(name, param.shape)
# Out:
# embed.W_E torch.Size([50257, 768])
# pos_embed.W_pos torch.Size([1024, 768])
# blocks.0.attn.W_Q torch.Size([12, 768, 64])
# blocks.0.attn.W_K torch.Size([12, 768, 64])
# blocks.0.attn.W_V torch.Size([12, 768, 64])
# blocks.0.attn.W_O torch.Size([12, 64, 768])
# *   Each attention layer plays a specific role in editing the concepts in the residual stream (these are more like ideas/themes/concepts rather than actual facts)
# *   The Attention head outputs heavily influence what knowledge is retrieved from the MLPs that follow it.
# *   Within an attention layer, individual heads may play even more specific roles (i.e. pronoun head, proper noun head, etc.)
# *   The MLPs act as knowledge stores. Based on the concepts in the residual stream, specific facts might be retrieved from the MLP and pushed into the residual stream.
#
#
#
# What we are doing here:
#
# *   We are going to project the outputs of each attention layer back into vocabulary space so we can see what concepts a particular layer is adding to the residual stream
# *   We will also do this at the individual attention-head granularity so we can emprically inspect if specific heads have specific themes/roles
#
# ![picture](https://drive.google.com/uc?export=view&id=13CQkZEsypvEHC24d3MZP1YQC1W5AgkIC)

# %%
# Function: head_latent_space_projector
# This function just projects the top K tokens from the latent space
# output of each head in a transformer back into vocabulary space so a
# user can assess what information is being put back into memory

# Users can toggle "intermediate_tokens" to see if they want to inspect
# the attention head outputs of intermediate tokens
# (or if they are only interested in the last token position)

def head_latent_space_projector(model, prompt, k_tokens, num_heads, aggregate_heads=True, intermediate_tokens=True):

  # intermediate_tokens = boolean arg that specifies if we want to the projections for all intermediate tokens as well, not just the last one

  #This is how you change if the outputs of heads are cached
  model.cfg.use_attn_result = True

  #tokenize the prompt
  tokens = model.to_tokens(prompt)
  logits, cache = model.run_with_cache(tokens, remove_batch_dim=True)

  if aggregate_heads:

    for l in cache:
      if "hook_attn_out" in l:

        head_results = cache[l][None, :, :]
        logits = model.unembed(head_results)

        topk_token_preds = torch.topk(logits, k_tokens)

        for i in range(len(tokens[0])):
          if not intermediate_tokens:
              print("LAYER: ", l)
              print("PROMPT: ", model.to_string(tokens[0][:]))
              print(model.to_string(topk_token_preds[1][0][-1].reshape(k_tokens, 1)))
              break
          print("LAYER: ", l)
          print("PROMPT: ", model.to_string(tokens[0][0:i+1]))
          print(model.to_string(topk_token_preds[1][0][i].reshape(k_tokens, 1)))
          print("---------")

  else: # This is incase we want each individual head
    for l in cache:
      if "hook_result" in l:

        head_results = cache[l][None, :, :]

        for h in range(num_heads):
          #head_out = ln_final[:,:, h, :]
          head_out = head_results[:,:, h, :]
          logits = model.unembed(head_out)
          topk_token_preds = torch.topk(logits, k_tokens)
          for i in range(len(tokens[0])):
            if not intermediate_tokens:
              print("LAYER: ", l, "| HEAD: ", h)
              print("PROMPT: ", model.to_string(tokens[0][:]))
              print(model.to_string(topk_token_preds[1][0][-1].reshape(k_tokens, 1)))
            break
            print("LAYER: ", l, "| HEAD: ", h)
            print("PROMPT: ", model.to_string(tokens[0][0:i+1]))
            print(model.to_string(topk_token_preds[1][0][i].reshape(k_tokens, 1)))
          print("---------")

# %%
prompt = "George Washington fought in the"
head_latent_space_projector(model=gpt2_small, prompt=prompt, k_tokens=10, num_heads=12, aggregate_heads=True, intermediate_tokens=False)
# Out:
# LAYER:  blocks.0.hook_attn_out
# PROMPT:  <|endoftext|>George Washington fought in the
# [' last', ' same', ' world', ' press', " '", ' "', ' way', ' open', ' special', ' quick']
# LAYER:  blocks.1.hook_attn_out
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' —', ' and', ' "', '.', ' the', ' state', ' today', '\n', ' Sunday']
# LAYER:  blocks.2.hook_attn_out
# PROMPT:  <|endoftext|>George Washington fought in the
# [' form', ',', ' last', ' early', ' air', ' civil', ' of', ' after', ' with', ' "']
# LAYER:  blocks.3.hook_attn_out
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' against', ' a', '\n', ' with', ' as', ',', ' He', ' The', ' two']
# LAYER:  blocks.4.hook_attn_out
# PROMPT:  <|endoftext|>George Washington fought in the
# [' last', ' the', ' and', ',', ' "', ' a', ' (', ' over', ' of', ' this']
# LAYER:  blocks.5.hook_attn_out
# PROMPT:  <|endoftext|>George Washington fought in the
# ['\n', ' himself', ' his', ' James', ' history', ' and', ' the', ' John', ' a', ' George']
# LAYER:  blocks.6.hook_attn_out
# PROMPT:  <|endoftext|>George Washington fought in the
# [' 1917', ' Roosevelt', ' 1914', ' 1916', ' naval', ' 1918', ' cavalry', ' Eisenhower', ' Infantry', ' war']
# LAYER:  blocks.7.hook_attn_out
# PROMPT:  <|endoftext|>George Washington fought in the
# [' battles', ' against', ' trenches', ' war', ' wars', ' skirm', ' and', ' trench', ' fights', ' during']
# LAYER:  blocks.8.hook_attn_out
# PROMPT:  <|endoftext|>George Washington fought in the
# [' wars', ' war', ' against', ' War', ' battles', ' fight', ' World', ' Grimm', ' Great', ' military']
# LAYER:  blocks.9.hook_attn_out
# PROMPT:  <|endoftext|>George Washington fought in the
# [' Washington', ' Congressional', ' treason', ' Confederate', ' Naval', 'Washington', ' wars', ' patri', ' warfare', ' military']
# LAYER:  blocks.10.hook_attn_out
# PROMPT:  <|endoftext|>George Washington fought in the
# [' Revolutionary', ' Virginia', ' wars', ' battles', ' Commonwealth', ' skirm', ' war', ' cavalry', ' Alaska', ' Washington']
# LAYER:  blocks.11.hook_attn_out
# PROMPT:  <|endoftext|>George Washington fought in the
# [' Continental', ' World', ' Revolutionary', ' Balk', ' Waterloo', ' Great', ' French', ' Cold', ' Camel', ' American']

# %%
prompt = "George Washington fought in the"
head_latent_space_projector(model=gpt2_small, prompt=prompt, k_tokens=30, num_heads=12, aggregate_heads=False, intermediate_tokens=False)
# Out:
# LAYER:  blocks.0.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' a', ' "', ',', '\n', ' and', ' in', '.', ' to', ' (', ' more', ' I', ' one', ' not', ' all', ' of', ' two', ' on', ' an', '-', " '", ' other', ' new', ' no', ' at', ' for', ' most', ' so', ' as', ' that']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>George Washington fought in the
# [' way', ' first', ' last', ' same', ' value', ' very', ' full', ' more', ' big', ' the', ' world', ' fair', ' difference', ' new', ' process', ' no', ' most', ' above', ' next', ' following', ' fact', ' quality', ' country', ' a', ' combination', ' whole', ' system', ' depth', ' move', ' latter']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', '\n', '-', '.', ' and', ' of', ' in', '/', ' the', ':', ' (', ' to', ' a', ' for', ' is', ' I', ' with', ' "', "'", ' from', '!', ' that', ' or', '\n\n', ' on', "'s", '?', ' as', '"', ' The']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' a', ' in', ' to', ',', ' "', ' and', ' all', ' not', '.', ' that', ' on', ' as', ' it', ' at', ' for', '\n', ' one', ' of', ' with', ' is', ' an', ' (', ' this', ' are', ' by', ' no', ' will', ' I', ' more']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' a', ' and', ',', '.', '\n', ' to', ' in', ' "', ' (', ' that', ' for', ' of', ' or', ' on', '-', ' is', ' as', ' at', ' it', ' one', ' an', ' The', " '", ' with', ' by', '/', ' not', ' all', ' I']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' "', ' and', '\n', ' a', ' be', ' in', ' to', ' work', ' other', ' place', ' more', ' good', ' high', ' first', ' for', ',', ' very', ' I', ' at', ' an', ' most', ' but', ' do', ' not', ' free', ' small', ' no', ' will', ' even']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', 'ramid', ' other', ' a', ' small', ' big', ' most', ' "', ' second', ' American', ' good', 'anwhile', ' former', ' new', ' very', ' one', ' about', ' more', ' half', ' own', ' not', ' what', ' government', 'and', ' two', 'atern', ' first', ' an', ' large', ' if']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' "', ' a', ' and', ' first', '-', ' it', ' l', ' U', ' p', ' all', ' to', ' m', ' b', ' M', ' that', ' or', ' of', ' time', ' them', ' on', ' h', ' c', ' in', ' you', ' day', ' r', ' C', ' one', '.']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>George Washington fought in the
# [' Resolution', ' resolution', ' recall', ' Enhanced', ' ABE', ' Stra', '{', ' Berlin', ' IC', ' Schneider', ' Scan', 'eret', ' Extended', ' CLSID', '/**', ' [', ' integrated', ' Frankfurt', ' block', ' process', ' Columbus', ' metropolitan', ':', ' CS', ' McC', ' Tro', 'dayName', ',', '-+', ' �']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>George Washington fought in the
# ['-', '\n', 'maxwell', ' ›', ' hockey', 'quartered', 'basketball', ' insulated', 'guyen', 'alted', 'rote', ' \u200e', 'min', 'etheless', ' lymph', ' gene', 'part', ' was', 'pad', 'jar', 'brids', 'cephal', 'waters', ' collagen', 'cision', ' agriculture', ' .', ' ...', 'amin', ' multiplayer']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>George Washington fought in the
# [' to', ',', ' the', ' in', ' and', ' a', ' on', ' that', '-', '.', ' just', ' or', ' him', ' all', ' me', ' of', ' (', ' at', ' out', "'s", ' away', ' over', ' as', ' so', ' this', ':', '\n', ' up', ' from', ' be']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>George Washington fought in the
# ['riot', 'yer', 'unts', 'ne', 'rain', 'else', 'crow', 'tre', 'ta', 'ridge', 'ens', 'e', 'ois', 'sc', 'lihood', 'ende', 'Jr', 'o', 'c', ' myster', 'yon', 'eric', 'root', '\n', 'ings', 'oak', 'C', 'theless', 'ecause', '"']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', '\n', ' a', ' and', ' first', ' to', ' as', ' of', '.', ' I', ' is', '-', ' in', ' (', ' The', ' "', ' for', ' that', ' or', ' A', ':', ' most', ' all', ' now', ' at', ' it', ' this', ' an', ' one']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>George Washington fought in the
# ['\n', ',', ' of', '-', '.', ' the', ' and', ' that', ' a', "'s", ' (', ':', ' in', ' to', ' "', ' state', ' this', ' for', ' on', '/', ' F', ' is', ' S', ' have', ' The', ' at', ' K', ' by', ' or', ' -']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>George Washington fought in the
# [' a', ' the', 'red', '\n', ' source', ' –', ' as', ' to', ' an', ' white', ' all', ' in', ' this', ' place', ' (', ' that', ' for', ' of', ' it', ' I', ' use', '.', ' there', ' make', ' light', ' people', ' have', ',', ' so', ' red']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' a', ',', ' it', ' and', ' in', '.', ' no', '-', ' of', ' to', ' as', ' there', ' at', ' v', '\n', ' that', ' for', ' is', ' did', ' "', ' or', ' an', ' maybe', ' other', ' all', ' by', ' on', ' do', ' was']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' of', ' in', ' a', ' the', ' and', ' to', ')', ' -', '\n', ' on', '.', ' it', ' said', ' at', ' for', ' one', ' with', ' that', ' or', '-', ':', ' have', ' (', ' not', ' there', ' but', ' by', ' from', ' behind']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' and', '.', ' a', ' to', ',', '\n', ' is', ' of', ' with', ' for', ' that', "'s", ' not', ' more', '-', ' (', ' in', ' as', ' from', ' you', ' this', ' very', ' such', ' I', ' all', ' "', ' has', ' also', ' at']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' and', '\n', ' the', '.', '-', ' a', ' (', ' of', ' or', ' in', ' to', ' "', '/', ' on', ' for', "'s", ' at', 'a', ' with', ' The', ' all', ' that', ' an', ' so', ' have', ' from', ' not', ' is', ' A']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' and', ' the', '.', ' in', ' to', ' of', ' "', ' it', ' a', '-', '"', ' that', ' at', " '", ' on', ' is', ' or', '\n', ' one', '/', ' —', ' was', ' even', ' with', ' he', ' as', ' for', ' from', ' then']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>George Washington fought in the
# ['\n', ' the', ',', '.', ' "', ' and', '-', ' in', ' a', " '", ' (', ' The', ' to', ' for', ' with', ' of', ' is', ' or', ' S', ' that', ' as', ' on', ':', ' I', ' M', ' from', ' 1', "'", '/', ' at']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', ' "', ' in', ' and', ' a', '.', '-', ' to', ' (', ' of', '\n', ' that', ' or', ' on', ' The', ' at', ' be', ' as', ' for', ' an', ' is', ' he', ' new', ' no', 'The', ' by', " '", ' it', '"']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>George Washington fought in the
# ['ICE', ' use', 'lder', 've', 'use', 'ms', 'hu', 'icy', 'rien', ' Solar', 'ro', ' D', 'ICES', 'med', ' Habit', 'ang', ' sun', ' Young', ' mood', 'elf', ' Mant', 'hare', 'ICO', 'IC', ' Pant', 'pard', 'ts', 'op', 'm', 'ic']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>George Washington fought in the
# [' and', ' "', ' (', ' the', '\n', ',', ' in', " '", ' a', ' no', ' as', ' to', ' The', ' on', ' M', ' with', ' that', ' New', ' not', ' it', '.', ' for', ' non', ' all', ' be', ' per', ' so', ' D', ' one', ' In']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>George Washington fought in the
# [' of', '\n', ' the', ' and', ',', ' The', ' to', 'The', '.', ' in', ' a', ':', ' not', ' "', ' true', ' for', ' here', ' even', ' (', ' as', ' like', ' also', '<|endoftext|>', ' on', '!', ' version', ' however', ' real', ' that', ' To']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', '.', ' in', ' a', ' "', ' of', '-', ' to', ' that', '\n', ' on', ' (', ' for', ' at', ' as', "'s", ' is', ' was', ' American', ' with', ' an', ' one', ' or', ' I', ' from', ' said', ' he', ' they']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' (', ' the', '.', ' a', ' of', ' as', '\n', ' and', ' "', ' to', ' form', ' for', ' A', ' that', ' other', ' at', ')', ' with', ':', ' more', ' all', ' hands', ' very', ' same', ' after', ' —', ' is', ' The', ' or']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' a', '\n', ' this', ' that', ' it', ' The', ',', ' as', ' and', ' not', ' I', ' one', ' an', ' to', ' (', '\n\n', ' so', ' both', ' at', ' in', ' some', ' which', ' these', ' only', '.', ' on', '-', ' all', ' each']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', ' a', '\n', '.', '-', ' (', ' in', ' to', ' "', ' for', '/', ' with', ' or', ' an', ' more', ' at', ' on', ':', ' that', ' all', ' this', ' as', "'s", ' it', ' is', ' I', ' of', ' -']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' of', ' and', ' in', ' "', '.', '\n', ' to', ' (', ' for', ' on', '-', "'s", ' the', ' with', ' that', ':', ' campaign', ' is', ' a', ' behind', ' are', " '", ' B', ' or', ' at', ' by', ' over', ' outside', ' The']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>George Washington fought in the
# ['.', ' and', ' the', ' to', ',', ' in', ' "', ' a', ' (', ' as', ' of', '-', ' or', '\n', ' for', ' with', ' at', ' on', ' that', ' by', ' over', '."', ').', ' but', ' not', ' it', ' is', ' from', ' just', ' so']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' in', '.', ' of', '\n', ' a', ' and', ' (', '-', ' to', ' for', ' "', ' on', ' with', ' is', '/', ' at', ' that', ' as', ' not', ' or', ' The', ' -', ' by', ' I', ':', ' from', ' an', "'s"]
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' of', '.', ' in', ' the', ' and', ' as', '\n', '-', ' at', ' (', ' -', "'", ' for', ' that', ' to', ' from', "'s", ' is', ' –', ' only', ' E', ')', ' with', ' was', ' by', ']', ' I', ' on', ' are']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>George Washington fought in the
# ['-', ' of', ' word', ' to', ' line', ')', ' and', ',', ' first', ' do', ' one', '/', ' game', ' the', ' in', ' is', '.', ' a', ' from', ' actual', ' big', '>', ' time', ' will', ' for', ' it', ' second', ' good', ' call', ' new']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>George Washington fought in the
# ['ap', 'asp', ' mathemat', ' colle', 'on', ' ASA', ' neighb', 'usk', 'ue', '.--', 'onse', ' suspic', ',', 'iol', 'oy', 'avid', 'ar', ' resil', 'ournal', 'is', 'hub', 'apy', ' reconc', 'haw', 'mos', 'emi', ' book', 'ave', 'maxwell', 'h']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', ' and', '.', '-', ' in', '\n', ' a', ' to', " '", ' of', ' or', "'s", ' is', ' "', ' that', ' it', ' at', ' (', ' for', ' with', ' on', ' I', ' from', ' as', ' just', ' was', ':', ' one', ' are']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' a', ',', ' and', '\n', ' of', '-', ' in', ' that', ' (', ' to', '.', ' "', ' all', ' other', ' this', ' or', ' it', ' have', ' an', ' on', ' with', ' I', ' The', '/', ' as', ' at', ' one', ' for', ' some']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', '.', '\n', ' and', ' a', ' in', ' to', ' "', ' (', ' as', ' that', ' for', '-', ' at', ' on', ' it', ' or', ' an', ' The', ' with', ' of', ' by', ' all', ' I', ' over', ' this', ':', ' is', ' from']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', '\n', ' a', ',', ' and', ' this', ' (', ' to', ' that', ' as', ' The', '.', ':', ' it', ' at', ' in', ' for', ' on', ' all', ' -', '\n\n', ' with', ' I', ' not', ' "', ' only', ' about', ' so', ' out', ' after']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' (', ' and', '\n', ' the', '.', ' in', ' of', ' a', '-', ' at', ' to', ' "', ' that', ' for', ' as', ' with', ' is', ' I', ' N', ' one', ':', ' on', ' A', ' first', ' from', ' was', ' The', ' high', ' most']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', '.', ' in', ' and', ' the', ' is', '\n', ' to', ' for', "'s", ' "', ' (', ' of', ' from', '-', ' was', ':', ' at', ' as', ' on', ' with', ' then', ' -', ' a', ' will', ' also', ' not', 's', ' just', ' [']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', ' in', ' and', '.', ' a', '\n', ' of', ' to', ' as', ' (', ' "', '-', ' for', ' on', ' with', ' at', ' The', ' that', ' was', ' one', ':', ' by', ' I', " '", ' is', ' an', ' not', ' but', ' it']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' of', ',', ' and', ' "', ' a', '-', ' in', '\n', '.', ' to', ' (', ' or', ' is', ' he', ' I', ' for', ' that', ' on', ' an', ' one', ' more', ' you', ' from', ' The', ' so', ':', ' with', ' they', ' are']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>George Washington fought in the
# ['-', ',', ' the', ' to', ' in', ' of', ' on', ' a', ' and', '.', ' time', ' that', ' it', ' for', ' all', ' with', ' from', ' up', " '", '/', ' more', ' do', ' I', ' at', ' is', ' one', ' "', ' or', ' have', ' an']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', '.', ' and', ' of', '\n', ' to', ' in', ' the', ' (', ' for', ' "', ' a', '-', ' with', ' on', ' is', ' or', ' that', ' as', "'s", ' by', ' at', ':', ' but', ' S', ' The', ' over', ' all', ' from', ' –']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' in', ' with', ' and', ' (', ' as', '.', '\n', ' for', ' a', ' of', ' at', '-', ' while', ' on', ' to', ' is', ' "', ' by', ' two', ' was', ' from', ' are', ' that', ' -', ' which', ' also', ' have', ' make']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' a', ' "', ' and', ' it', ' you', ',', '.', ' is', '\n', ' to', ' that', ' of', ':', ' in', ' be', " '", ' do', ' P', ' have', ' what', ' I', ' your', ' (', '-', ' new', ' S', ' we', ' on', ' all']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' a', '\n', ' and', ',', ' in', '-', ' to', '.', ' (', ' as', ' for', ' that', ' I', ' or', ' at', ' "', ' not', ' of', ' now', ' so', ' more', ' on', ' The', ' one', ' K', "'s", ' an', ' be', ' by']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', '\n', ' (', ' and', ' the', '-', '.', ' of', ' on', ' a', ' in', ' or', ':', ' for', ' at', ' over', ' is', ' as', ' "', "'s", ' [', ' with', ' The', ' –', ' —', ' I', ' can', ' will', ' all', ' to']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', '.', '\n', ' and', ' the', ' a', ' to', ' in', ' (', '-', ' as', ' at', ' of', ' for', ' with', ' on', ' that', ' The', ' "', ':', ' or', ' but', '/', ' by', ' this', ' an', ' one', ' after', ' not', ' is']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', ' in', '.', ' to', ' a', ' of', '\n', ' "', ' (', ' for', '-', ' that', ' on', ' as', ' with', ' at', ' is', ' or', ' it', ' by', ' not', ' I', ' one', ' from', ' also', ' only', "'s", ' an']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', '.', ' and', '\n', ' in', ' of', ' a', ' (', '-', ' to', ' with', ' "', ' that', ' or', ' is', ' at', ' from', ':', ' The', ' as', ' on', ' it', ' for', ' an', ' this', ' one', '/', ' have', ' -']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', '\n', '.', ' and', ' in', ' a', ' of', ' to', ' (', ' "', ' or', ' for', '-', ' all', ' is', ' as', ' that', ' I', ':', ' this', ' at', ' on', ' with', ' new', ' one', ' not', '/', ' from', ' are']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' a', ' and', ',', '\n', ' in', ' to', ' of', '-', ' that', '.', ' "', ' (', ' for', ' is', ' an', ' on', ' this', ' one', ' The', ' with', ' I', ' all', ' at', ' it', ' or', ' not', ' from', "'s", " '"]
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', " '", ' the', ' and', ' "', ' a', ' of', ' to', ' for', ' in', ' (', '-', ' on', ' A', ' that', ' it', '.', ' who', ' G', ' or', ' one', ' M', ':', ' is', ' not', '\n', ' F', ' [', ' S', ' first']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>George Washington fought in the
# ['ufact', '\n', ' ships', ' should', ' Osc', ' and', ' is', ' =', ' must', ' streng', ' pharmacies', ' return', ' problem', ' needed', ' esc', ' would', ' used', ' o', ' href', ' etc', 'ér', ' responds', 'vre', ' was', ' adv', ' ingred', ' taxp', ' the', 'Ps', ' quo']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', ' a', '.', '\n', ' and', ' in', ' to', ' of', '-', ' (', ' that', ':', ' for', ' "', ' at', ' is', ' as', ' with', ' on', ' it', " '", ' from', ' one', ' or', ' I', "'s", ' was', ' all', ' an']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' a', ' and', ' to', ' in', ',', ' that', '.', ' with', ' at', ' (', ' for', ' all', ' an', ' The', ' of', ' this', ' last', ' which', ' "', ' as', ' on', ' from', ' it', ' was', '\n', ' both', ' his', ' made', ' before']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' and', ' the', ' in', '.', ' to', '\n', ' of', ' a', ' (', '-', ' "', ' on', ' for', ' at', ' that', ' as', ' with', ' or', ' by', ' is', ' from', ':', ' not', '/', "'s", ' I', ' it', ' so', ' all']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' and', ' to', ' in', ' "', ' the', ' of', '-', ' for', ' as', '.', ' on', ' at', '\n', ' first', ' high', ' or', ' a', ' last', ' (', ' that', ' with', ' form', ' over', ' so', ' early', ' out', " '", ' B', ' new']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' in', ' a', ',', ' and', ' of', ' to', ' that', '\n', ' "', '.', ' this', ' as', ' on', ' with', ' for', ' or', ' is', '-', ' (', ' all', ' at', ' has', ' have', "'s", ' not', ' by', ' you', ' so', ' here']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', '.', ' the', ' in', ' and', ' a', ' to', ' (', ' of', '\n', ' for', ' that', ' as', ' on', ' more', ' "', ' The', ' or', ' by', ' at', ' is', '-', ' with', ' even', ' not', ' after', ' it', ' also', ':', ' -']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' a', ',', ' and', '\n', ' in', ' to', ' with', '.', '-', ' for', ' "', ' this', ' not', ' all', ' but', ' of', ' first', ' an', ' very', ' as', ' one', ' (', ' at', ' is', ' more', ' on', ' two', ' it', ' his']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', '.', ' and', ' a', '\n', ' in', ' The', ' "', ' at', ' as', ' to', ' that', ' (', '-', ' but', ' for', ' on', ' of', ' was', ' by', ' his', ' when', ' an', ' In', ' I', ':', ' with', ' both', ' which']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>George Washington fought in the
# ['\n', ',', ' in', ' and', ' the', ' of', '-', ' (', '.', ' for', ' to', ' a', ' or', ' "', " '", ' on', ' as', "'s", ' at', ' that', ' [', ' with', ' I', ' more', ' first', ' by', ' is', ' The', ' when', ' 1']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' a', ' and', '\n', ' to', ' "', ' in', '.', ' of', '-', ' or', ' (', ' on', ' all', '/', ' for', ' at', ' that', ' last', ' with', ' some', ' this', ' an', ' A', ' it', ' one', ' F', ' other', ' have']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' and', ' the', '\n', '.', '-', ' in', ' of', ' a', ' to', ' (', ' "', ' that', ' is', ' for', ' at', ' on', ' or', ' as', ' I', ' with', ':', ' A', ' from', ' The', "'s", ' all', ' one', ' it', ' are']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>George Washington fought in the
# [' and', ' the', ',', ' a', '\n', ' against', '.', ' in', ' (', '-', ' with', ' to', ' on', ' as', ' one', ' over', ' an', ' at', ' for', ' front', ' -', ' is', ' of', ' push', ' "', ' I', ' [', ' have', ' will', ' side']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', '\n', ' and', ',', ' this', ' a', ' to', ' in', ':', ' that', ' of', ' (', '-', '.', ' I', ' or', ' [', ' he', ' "', ' with', ' these', ' on', ' as', ' we', ' M', ' for', ' J', "'s", ' there', ' The']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>George Washington fought in the
# ['Dialogue', 'enum', 'thia', 'uckles', 'row', 'omsky', 'addon', 'onica', 'otom', ' path', 'xit', 'chnology', 'ificate', ' <', ' =>', 'edom', 'owship', 'ename', 'orage', 'berus', 'assin', 'asus', ' elders', 'zon', 'URN', 'tein', 'antha', 'llah', 'toc', 'accompan']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' and', ' the', ' in', '.', '\n', ' a', ' of', ' to', ' his', ' history', ' great', ' James', ' John', ' himself', '-', "'s", ' he', ' time', ' one', ' two', ' (', ' as', ' at', ' back', ' &', ' or', ' He', ' was', ' Hon']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>George Washington fought in the
# ['\n', ',', '.', ' (', '-', ' the', ' and', ' "', ' of', ' a', ' for', ' to', ':', ' is', ' in', " '", ' that', ' The', '<|endoftext|>', ' A', ' it', ' M', ' or', ' I', ' S', ' can', ' new', ' P', ' source', ' you']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', ' a', ' in', ' and', ' himself', ' as', ' with', ' to', ' last', ' on', ' at', ' of', ' (', '.', ' his', ' for', ' this', ' "', ' before', ' when', ' an', ' early', ' not', ' by', '\n', ' that', ' very', ' first', ' during']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', '\n', '.', ' in', ' and', ' to', ' a', ' of', ' (', ' "', ' is', ' on', '-', ' for', ' that', ' as', ':', ' at', ' with', ' The', ' or', ' I', ' by', ' from', "'s", ' it', ' are', ' was', ' this']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', '\n', ' in', '-', ' a', '.', ' "', ' of', ' to', ' that', ' or', ' as', ' on', ' (', ' all', ' for', ' at', ' it', ' is', " '", ' by', "'s", ' The', ';', ' was', ' this', ' an', ' with']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>George Washington fought in the
# ['\n', ',', ' the', ' and', '.', ' in', ' a', '-', ' of', ' (', ' to', ' for', ' "', ' on', '/', ' is', ':', ' with', ' or', ' as', ' that', ' The', ' at', ' this', ' I', ' all', "'s", '<|endoftext|>', ' by', ' other']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>George Washington fought in the
# [' Roosevelt', ' Commonwealth', ' cavalry', ' treaties', ' naval', ' troop', ' treaty', ' Corps', ' Confederate', ' peac', ' Treaty', ' exped', ' war', ' warfare', ' Infantry', ' aid', ' troops', ' peace', ' War', ' William', ' nation', ' land', ' Frederick', ' defeat', ' railroad', ' military', ' doctrine', ' Colossus', ' Washington', ' Eisenhower']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', '-', '\n', ' to', ' "', '.', ' of', ' a', ' that', ' (', ' in', ' or', ' for', ' it', ' is', ' one', ' I', ' would', ' if', "'s", '/', ' on', ' D', ' more', ' not', ' -', ' be', ' they']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', ' and', '\n', ' a', ' in', ' (', ' or', ' to', ' is', '-', ' of', ' for', ' it', ' are', '.', ' "', ' that', ' I', ' at', ' all', ' not', ' most', ' as', ' G', ' [', ' P', ' .', ' on', ' like']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' and', ' in', ' the', '.', ' a', ' (', '-', ' history', ' of', '\n', ' that', ' to', ' as', ' from', ' "', ' for', ' on', ' I', ' is', ' but', ' he', ' historical', '/', " '", ' or', ' with', ' two', ' national', "'s"]
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>George Washington fought in the
# [' to', ' the', ' a', ' in', ' on', ' of', ' "', ' for', ' with', ' at', ' and', ',', ' as', ' from', ' (', ' through', ' into', '\n', ' all', ' an', ' out', ' more', ' like', ' not', ' one', ' n', ' free', ' that', ' by', ' or']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', '.', '\n', ' and', ' in', ' (', ' a', ' of', ' to', ' The', '-', ' for', ' on', ':', ' with', ' that', ' "', ' is', ' at', ' -', "'s", ' A', ' as', ' I', ' or', ' by', ' from', 'The', ' has']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', ' in', ' a', '\n', ' to', '.', ' of', '-', ' "', ' (', ' with', ' for', ' or', ' that', ' is', ' as', ' was', ' The', ' I', ' -', ' it', ' all', ' from', ' at', ':', ' A', ' on', ' an']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>George Washington fought in the
# [' and', ',', '.', ' the', '-', '\n', ' (', ' a', ' of', ' in', ' "', ' for', ' to', ' as', ' that', ' with', ' The', ' from', ' I', ' at', ' on', ' is', ' -', ' also', ' most', ':', ' but', ' all', ' first', ' two']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>George Washington fought in the
# [' and', ' of', ' the', ',', ' in', ' a', ' (', ' or', ' to', ' on', ' for', ' with', "'s", ' that', '\n', '.', ' "', ' The', ' at', ' as', ' court', '-', ' I', ' by', ':', ' war', ' not', ' first', ' #', ' is']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' and', ' the', ' in', '\n', '-', ' of', ' to', '.', ' a', ' (', ' "', ' or', ' for', ' with', ' on', ' as', ' at', ' that', "'s", ' is', '/', ':', ' I', ' The', ' -', ' from', ' not', ' A', ' an']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', '\n', ' a', ' and', ' "', '.', ' to', ' in', ' (', '-', ' of', ':', ' for', ' at', ' more', ' is', ' The', ' that', ' as', ' or', ' with', ' on', " '", ' all', ' it', ' this', ' [', ' an', ' from']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' and', ' a', ' to', ' -', ' "', '\n', ' or', ' one', ' the', ' (', ' that', '-', ' in', ' of', '/', ' it', ' –', ' for', ' I', ' no', ' as', ' n', ' more', ' others', ' an', ' all', '.', ' not', ' most']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', '\n', '.', ' a', ' in', ' and', ' as', ' to', ' of', ' with', ' for', ' on', ' at', ' (', ' "', ' that', '-', ' not', ' it', ' from', ' all', ' so', ' but', ' an', ' is', ' or', ' just', " '", ' I']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', '\n', ' and', ' in', ' (', ' a', ' of', ' to', ' was', '.', ' first', '-', ' on', ' that', ' he', ' "', ' The', ':', ' at', ' during', ' from', ' for', ' with', ' early', ' [', ' as', ' A', ' In', " '"]
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' and', '.', ' to', ' the', ' a', ' (', ' in', ' of', '\n', ' or', '-', ' "', ' for', ' that', ' by', ' as', ' is', ' all', ' .', ' with', ' not', ' it', ' only', ' an', ' at', ' again', ' from', ')', ' new']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' and', ' a', ' in', '\n', ',', ' to', '.', ' of', ' (', ' on', '-', ' for', ' at', ' as', ' "', ' is', ' with', ' or', ' all', ' that', ' an', ' one', ' it', ' I', ' The', ' by', ' other', ' not', ' from']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>George Washington fought in the
# [' against', ' battles', ' brave', ' alongside', ',', ' in', ' on', ' battle', ' with', ' while', ' valiant', ' and', '.', ' fight', ' fighting', ' action', ' the', ' #', ' fights', ' fought', ' passionately', ' line', ' solo', ' long', ' over', ' a', '\n', ' marathon', ' team', ' endurance']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', '\n', ' a', ',', ' to', ' and', ' in', ' "', ' his', ' of', '-', ' he', ' (', '.', ' The', ' that', ' I', ' for', ' with', ' as', ' on', ' at', ' her', ' not', " '", ' or', ' by', ' this', ' all', ' He']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' in', '.', ' and', '\n', ' a', ' to', ' of', ' (', ' with', ' on', ' for', ' "', ' that', ' is', ' as', '-', ':', ' at', ' this', ' The', ' I', ' from', ' by', ' it', ' an', ' or', ' one', ' was']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', '.', ' and', ' a', ' to', ' in', ' is', ' of', '\n', '-', ' that', ' for', ' with', ' it', ' as', ' (', ' was', ' on', ' "', ' or', ':', "'s", ' are', ' at', '/', ' this', ' has', ' from', ' all']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>George Washington fought in the
# ['},', '}', '...', '.', '}.', ']', ').', ',', '].', ' the', '--', '-', '};', ' and', ')', '],', '})', '),', '>,', ' them', ' a', '."', ' I', ' latter', '—', ' }', '>', ' f', '…', '|']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', '\n', ',', '.', ' a', ' "', ' in', ' and', ' that', ' to', ' of', ' (', ' for', ':', ' is', ' The', ' it', ' not', ' at', ' as', '-', ' -', ' with', ' more', ' an', " '", ' on', ' all', ' I', ' one']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', ' a', '\n', ' and', '.', ' in', ' to', ' of', ' "', '-', ' or', ' for', ' on', ' at', ' with', ' he', ' The', ' an', ' —', ':', ' that', ' his', ' was', ' A', ' as', ' by', ' (', ' from', ' is']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' in', ' the', '\n', ' and', ' a', ' to', '-', ' for', '.', ' (', ' of', ' at', ' "', ' on', ' I', ' with', ' as', ' you', ' The', ' or', ' support', ' an', ' is', ' S', ' work', ' all', ' A', ' we', ' not']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>George Washington fought in the
# [' against', 'against', ' Against', ' fight', ' for', '.', ' battles', ' vs', ' in', ' on', ' to', ' with', ',', ' and', ' battle', ' the', ' attack', ' support', ' war', ' before', ' true', ' protect', ' defend', '-', ' up', ' force', ' close', ' back', ' over', ' try']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>George Washington fought in the
# ['\n', ' the', ' a', ' famous', ' in', ' was', ' and', ' famously', ' that', ' when', ' his', ',', ' "', ' of', ' many', ' during', ' for', ' one', ' as', ' to', ' he', ' famed', ' never', ' years', '.', ' lived', ' with', ' so', ' life', ' had']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', '.', ' and', ' in', '\n', '-', ' to', ' a', ' of', ' "', ' (', ' on', ':', ' for', ' is', ' that', ' with', ' as', ' was', ' at', ' I', ' or', '/', "'s", " '", ' from', ' The', ' -', ' it']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>George Washington fought in the
# [' battle', ' war', ' competition', ' fight', ' battles', ' role', ' wars', ' trials', ' fights', ' contests', ' conflict', 'battle', ' country', ' in', ' World', 'clave', ' action', ' situations', ' fray', ' with', ' field', ' meetings', ' desert', ' bouts', ' event', ' wilderness', ' duel', ' by', ' world', ' bout']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', ' in', '\n', '.', ' of', ' a', ' to', ' (', '-', ' on', ' "', ' at', ' is', ' that', ' for', ' with', ' as', ' or', ' United', ' I', ' it', ' The', ' from', ' this', ' was', ' by', ' international', ':']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' and', ' the', ' of', ' original', ' a', ' to', ' "', ' (', ' memories', ' in', ' for', ' from', ' remembered', ' historical', '.', " '", '-', ' book', ' that', ' one', ' biography', ' title', ' it', ' memory', ' Book', ' is', '\n', ' or', ' history']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>George Washington fought in the
# [' parameters', ' data', 'MM', 'medi', 'acceptable', ' error', ' parameter', 'x', 'mod', ' KB', ' algorith', 'ebin', 'data', 'meta', ' digital', 'effic', 'px', 'Add', ' manually', 'Index', 'β', 'correct', 'larg', ' x', 'output', 'Internal', 'σ', ' below', 'ohm', ' aggreg']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>George Washington fought in the
# [' Washington', ' George', ' the', ' Jefferson', ' a', ',', ' Adams', ' Louis', ' General', ' and', '.', ' of', ' 17', ' "', ' Duke', '\n', ' Ferguson', ' (', ' to', ' United', ' that', ' US', ' Garrison', ' in', ' Bourbon', ' U', ' Fort', ' for', ' Prince', ' War']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', '.', '\n', ' a', ' in', '-', ' to', ' of', ' (', ' "', ' for', ' or', ' as', ' that', ' is', ' with', ' at', ' I', '/', ' an', ' not', "'s", ' all', ':', ' on', ' by', ' was', ' this']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', '\n', ' and', '.', ' in', ' a', ' (', '-', ' of', ' to', ' "', ' is', ' on', ' for', ':', ' with', ' at', ' I', ' that', "'s", ' one', ' from', ' or', ' not', " '", ' by', ' was', ' The', ' it']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>George Washington fought in the
# [' fighting', ' battle', ' military', ' fought', ' war', ' fight', ' battles', ' combatants', ' soldier', ' soldiers', ' Battle', ' fighters', ' troops', ' fights', ' fighter', ' wars', ' combat', ' victory', ' warrior', ' warfare', ' Soldiers', ' Victory', ' battlefield', ' warriors', ' victorious', ' vict', ' Warrior', ' patriotic', ' army', ' Battles']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>George Washington fought in the
# [' wars', ' war', ' assassinated', ' invasion', ' assassination', ' rebellion', ' riots', ' genocide', ' fight', ' uprising', ' murders', ' warfare', ' murder', ' insurrection', ' famine', ' massacre', ' earthquakes', ' murdered', ' outlaw', ' death', ' revolt', ' revolution', ' siege', ' apartheid', ' Nazi', ' fought', ' earthquake', ' Nazis', ' battles', ' fights']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', ' and', ' a', ' in', ' to', ' of', '\n', '.', ' (', '-', ' all', ' that', ' as', ' for', ' or', ' an', ' is', ' more', ' at', ' this', ' other', ':', ' one', ' on', ' with', ' not', ' 2', ' from', ' first']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' (', ' and', ' to', '-', ' the', ' is', ' can', ' a', ' or', ' of', '\n', '/', '.', ' in', ' for', ' "', ' as', ' will', ' C', ' it', ' with', ' are', ' that', ' M', '(', ' on', ' I', ' do', 's']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', ' a', ' in', '\n', ' and', '.', ' to', ' of', ' for', '-', ' that', ' (', ' "', ' at', ' on', ' The', ' is', ' as', ' it', ' this', ' with', ' one', ' not', ' an', ' I', ' or', ':', ' -', ' all']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', '\n', ' he', ' his', ' that', '.', ' in', " '", ' "', ' and', ' of', ' a', ' to', ' He', ' (', '-', ' for', ' so', ' then', ' as', ' you', ' D', ' at', ' this', ' it', ' later', ' on', ' with', ' him']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>George Washington fought in the
# [' Washington', 'Washington', ' Virginia', 'Virginia', ' Maryland', ' Congressional', ' Georgetown', ' Dull', ' Smithsonian', ' Maine', ' Burr', ' Jefferson', ' Navy', ' Capitol', ' congressional', ' FDR', ' Lexington', ' Byrd', ' Rhode', ' Roosevelt', ' Pike', ' Everett', ' Brookings', ' Madison', 'apeake', ' Randolph', ' VA', ' Arlington', ' Americans', ' Lafayette']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', '\n', '.', ' a', '-', ' in', ' to', ' of', ' (', ' "', ' on', ' for', ' is', ' that', ' with', ' as', ' or', ':', ' at', ' The', ' I', '/', "'s", ' by', ' not', ' one', ' it', ' was']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' and', ',', ' in', ' a', ' on', ' of', ' at', ' that', ' for', ' "', ' as', ' to', ' with', ' also', ' always', ' only', ' all', ' not', ' (', '\n', ' against', ' more', ' one', ' will', ' often', ' is', ' over', ' was', ' like']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', '.', '\n', ' in', ' to', ' a', ' of', ' is', ' for', ' on', ' as', ' that', ' or', ' with', ' at', ' "', ' it', ' (', ' from', ' not', ' one', ' but', ' by', ' was', '\n\n', ' all', ' are', ' The']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>George Washington fought in the
# [' Washington', ' Virginia', 'Washington', ' Georgian', 'izon', ' Russia', 'Alexander', ' Russian', ' Georgetown', ' Alexander', ' the', ' Maryland', ' Capitals', ' Revolutionary', ',', ' and', ' Chen', ' a', '.', ' Fairfax', ' Alexandria', '\n', ' George', ' in', ' Prince', ' of', ' to', ' Ches', ' Ukrain', 'Virginia']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', '.', ' a', '\n', ' in', ' of', ' to', '-', ' (', ':', ' for', ' "', ' is', ' that', ' on', ' as', ' or', ' with', ' at', ' I', '/', ' was', ' not', ' by', ' have', ' it', ' has', ' all']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', ' a', '.', ' to', ' in', '\n', ' of', '-', ' for', ' on', ' "', ' that', ' as', ' (', ' is', ' at', ' or', ' with', ':', ' all', ' this', ' it', ' -', ' so', ' one', ' from', ' have', ' not']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>George Washington fought in the
# ['\n', ',', ' and', ' the', ' a', '.', ' (', ' in', '-', ' to', ' of', ' "', ' or', ' for', ' with', ' that', ' as', ' is', ' on', ' I', ' at', '"', '/', ' more', ' by', ' an', ' The', ' not', ' one', "'s"]
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' and', ',', '.', ' a', ' I', ' to', ' in', ' of', ' (', ' that', ' or', '-', ' The', ' for', '\n', ' is', ' "', ' this', ' as', ' it', ' A', ':', ' at', ' you', ' with', ' on', ' -', ' one', ' by']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' and', ' the', '\n', ' in', ' to', ' a', ' (', ' when', ' before', '.', ' at', ' "', ' of', ' on', ' that', ' not', ' for', ' as', ' so', ' after', ' with', ' is', ' first', ' was', ' -', '-', ' but', ' from', ' because']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', ' a', '\n', ' and', '.', ' to', ' in', ' (', '-', ' "', ' for', ' of', ' war', ' is', ' that', ' I', ' on', ' with', " '", ' The', ' it', ' this', "'s", ' at', ' all', ' from', ' more', ':', ' have']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>George Washington fought in the
# [' Nina', ' NE', ' CN', ' �', ' NM', ' privacy', ' ND', ' list', 'cn', ' NA', ' OCT', ' CL', ' PAN', '-', ' N', ' Wi', ' non', ' PNG', ' ""', ' NX', ' Len', ' #', ' IP', ' Privacy', ' NT', ' Tina', ' the', ' PE', 'NT', ',']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>George Washington fought in the
# ['\n', ' (', ' and', ' "', '.', ',', ' the', ' to', ' of', ' is', ' I', ' for', ' in', ' -', ' other', ' a', ' [', ' will', ' are', ' was', ' The', ' very', ' it', ' with', ' more', ' –', ' we', ' can', " '", '...']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>George Washington fought in the
# [' his', ' the', '.', ',', ' he', ' to', ' for', ' in', ' and', ' a', ' that', ':', ' "', ' on', ' of', ' him', ' this', ' as', '\n', ' The', ' is', ' with', ' He', ' I', ' other', ' such', ' His', "'s", ' (', ' one']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', ' a', '.', ' in', '-', ' to', ' "', '\n', ' of', ' (', ' for', ' as', ' or', ' on', ' with', ' that', ' d', ':', ' at', ' an', ' D', '/', "'s", ' one', ' is', ' by', ' it', " '"]
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>George Washington fought in the
# [' battles', ' wars', ' fights', ' war', ' contests', ' battle', ' fight', ' races', 'fights', ' Battles', ' contest', ' matches', ' War', ' conflicts', ' conflict', ' Wars', ' games', ' race', ' debates', ' competitions', ' skirm', ' the', ' fires', ' campaigns', ' campaign', ' Battle', ' cause', ' fought', ' clashes', ' armed']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>George Washington fought in the
# [' glim', ',', ' the', ' destro', ' proble', ' cryst', ' nodd', ' a', ' tiss', ' thous', '-', '.', ' m', ' of', ' and', ' M', ' obser', ' to', ' L', ' be', ' watch', ' Kron', ' you', ' redes', ' sacrific', ' in', ' Portug', ' or', ' punk', ' l']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>George Washington fought in the
# ['\n', ',', ' I', ' the', ' and', '-', ' (', ' A', ' a', '.', ' in', ' to', ' C', '/', ' W', ' for', ' E', ' B', ' of', ' D', ' 4', ' post', ' is', ' 3', ' S', ' or', ' n', ' 2', ' N', ' e']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' D', '.', ' and', ' a', ' in', ' of', ' to', '\n', '-', ' is', ' R', ' S', ' I', ' "', ' T', ' (', ' or', ' have', ' for', ' F', ' V', ' M', ' E', ' on', ' it', ' that', ' are', ' A']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>George Washington fought in the
# [' war', ' military', ' battle', ' troops', ' combat', ' War', ' soldiers', ' Army', ' fighting', ' battlefield', ' army', ' fight', ' battles', ' wars', ' Battle', 'war', ' fought', ',', ' soldier', ' the', ' Military', ' veterans', '\n', 'Army', ' defeated', ' and', ' generals', '.', ' warrior', ' a']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>George Washington fought in the
# [' exha', ' mathemat', ' confir', ' condem', ' destro', ' occas', ' proble', ' Seym', ' behavi', ' conduc', ' suspic', ' Palestin', ' notor', ' Ukrain', 'sylv', ' enthusi', ' Vaugh', 'accompan', ' encount', ' convol', ' contrace', ' skelet', ' unden', 'ヴ', ' mosqu', ' psychiat', ' Afric', ' sugg', ' redes', ' cannabin']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ',', ' and', ' a', '\n', ' in', '.', '-', ' to', ' (', ' of', ' "', ' for', ' P', ' I', ' that', ' on', ' B', ' with', ' K', ' M', ' as', ' he', ' R', ' F', ':', ' other', "'s", ' at', ' it']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', ' in', '.', ' a', '\n', ' to', ' of', '-', ' (', ' "', ' on', ' for', ' at', ' as', ' that', ' or', ' one', ' with', ' by', ' not', ' from', ' all', ' is', ':', ' more', ' under', ' I', ' it']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>George Washington fought in the
# [' the', ' he', ',', '\n', ' a', ' his', ' in', ' R', ' (', ' and', ' D', ' him', ' to', ' T', ' is', '.', '-', ' of', ' "', ' O', ' He', ' The', " '", ' at', ' J', ' that', ' on', ' B', ' for', ' was']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>George Washington fought in the
# ['\n', ' the', ' in', ' "', ' and', ' The', ' a', ' of', ' I', ' to', '-', ',', '.', ' U', ' at', ' St', ' In', ' (', ' on', ' that', ' is', ' 1', ' A', ' P', ' for', ' an', ' He', ' from', "'s", ' 4']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>George Washington fought in the
# [',', ' the', ' and', '.', ' a', '\n', ' in', ' of', ' to', '-', ' (', ' "', ' I', ' is', ' that', ' on', ' for', ' with', ' at', ':', "'s", ' or', ' as', ' all', ' from', ' it', ' not', ' The', ' was', '/']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>George Washington fought in the
# [' Celt', ' CT', ' T', ' TB', ' FD', ',', ' Lyft', ' TG', ' Dor', ' TC', ' Lazarus', ' D', ' the', ' F', ' Cuban', ' and', ' Celtic', ' TF', ' Frost', ' Ruff', ' Doyle', ' in', '.', ' Dru', ' f', ' Cork', ' Tart', ' Dar', ' a', '-']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>George Washington fought in the
# ['\n', ',', ' the', ' and', '.', ' to', ' in', ' a', ' (', ' of', ' "', ' on', ' The', ' for', ' is', ' at', ' as', ' that', ' with', ' A', ' not', ' or', ' I', ' P', ':', ' have', ' an', ' from', ' will', ' by']
# ---------

# %%
prompt = "The first president of the United States fought in the"
head_latent_space_projector(gpt2_large, prompt, 10, 20, aggregate_heads=False, intermediate_tokens=False)
# Out:
# LAYER:  blocks.0.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', '-', ' for', '\n', ' of']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', '-', ' to', ' of', ' in', ' the', ' for']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', '-', ' to', ' of', ' or', ' for']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', '\n', ' to', ' of', ' the', ' for']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' of', ' to', '-', '\n', ' or']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' of', ' for', ':', ' the']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', '-', ' of', ' for', ' the']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', '-', ' to', ' the', ' or', ' at']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', '\n', '-', ' to', ':', ' of']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', ' of', '-', ' or', '\n']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', '-', ' of', '\n', ' for']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' of', ' in', ' to', '-', ' the', ':']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', '-', ' of', ' or', ' the']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' in', ' to', ' the', ' of', ' (', '\n', ' for']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', ' (', ' the', '.', '\n', ' in', ' of', '-', ' to']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', '\n', ' of', ' for', ':']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' the', ' of', '-', '\n']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' to', ' in', ' of', '-', '\n', ' the']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', '-', ' to', ' in', ' of', ' for', ' the']
# ---------
# LAYER:  blocks.0.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', '\n', ' to', ' of', '-', ' the']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', ' the', '\n', ' for', ':']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ' a', ',', ' about', ' with', ' outside', ' on', ' to', ' (', "'s"]
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', '-', '\n', ' with', ' of', ' to']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' of', ' and', '-', ':', '.', ' (', '\n', ' in', ' –']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', '\n', ' in', ' (', ' the', ' of', ' to', ':']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' to', ' in', ' of', '-', ' for', '\n']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' in', '.', ' to', ' of', '\n', ' the', ' (', '-']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' in', ' (', '-', ' to', ' the', ' of', ' for']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' of', ' in', '\n', ' to', ' the', '-']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' of', '.', ' or', ' in', ' (', '-', ' to', ' the']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' in', ' (', ' to', ' of', ' the', '\n', ' or']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', '\n', ' the', ':', '-', ' to']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', '.', ' and', ' (', ' with', ' in', ' –', ' to', ' of', '\n']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', '\n', ' to', '-', ' of', ' for']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', '-', ':', ' of', '\n']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', '-', ' in', ' to', ' of', ' for', '\n']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', ' in', ' (', ' of', '.', '\n', ' to', ' or', ' for']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' the', ' in', ' to', '\n', ' or', ' of']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', '-', ' (', ' in', ' or', ' to', ' of', ' for']
# ---------
# LAYER:  blocks.1.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', '.', ' and', ' in', ' (', '\n', ' to', ' the', ' for', ' a']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' of', ' for', ' (', ':', ' at', '-', ' with']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' or', ' in', '-', ' to', '\n', ' of']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' in', ' (', '\n', '-', ' of', ' to', ' on']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', ' (', '-', '.', ' of', '\n', ' in', ' to', ' or']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' of', '-', ' to', ' in', '—', ' for', '.', ' by']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', '-', ' in', ' (', ' to', ' of', ' the', ' at']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' in', ' of', ' to', '.', ' or', ' for', '-']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', '-', '\n', ' in', ' or', ':', ' to']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['.', ',', ' \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0', '.(', ' \xa0 \xa0', ' (', " ('", ' [(', ' Nu', '\n\xa0']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '\n', '.', ' of', ' to', ':', ' in', '-']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '\n', '.', ' in', ' (', ' of', ' or', '-', ' to']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' of', ' in', ' to', ' (', '.', '-', ':', ' or']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', ' the', ' of', ' or', '/']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' to', ' the', ' in', ' of', '.', ' (', '\n', ' for']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', '-', ' for', ' to', '/', ' at']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', '\n', ' (', '.', "'s", ' or', ' in', ' to', ' on']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' the', ' in', '\n', ' to', ' of', '-']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', '.', ' or', ' (', '-', ' to', ' in', ' of', ' that']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', '\n', ';', ' to', ' or', '-', ' in']
# ---------
# LAYER:  blocks.2.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', ' (', '.', '\n', ' in', ' of', ' to', ' on', ':']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' Pref', 'earch', ' promot', ' accomp', 'soType', ' Recre', ' Treat', 'ilde', ' suspic', 'oufl']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '-', ' (', ' -', ' in', ' to', '\n', ' of', '.']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', '(', ' to', '-', ' in', ' or', ' of']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' of', ' and', ' in', '\n', '.', ' to', ' the', ':', '-']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '\n', ' the', '.', ' (', ' in', ':', ' from', ' to']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', ' (', ' or', ' to', ' in', ' the', ' with', '.', ' of']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' of', ' the', '-', ' to', '\n']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', '-', ' of', ':', ' to', ' or']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['\n', ',', ' and', '.', ' (', ' the', ' in', '-', ' of', ' with']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' in', ' (', ' of', ' to', '-', ' on', ' for']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', '-', ' to', '\n', ':', ' or']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' to', ' in', ' of', ' that', ' (', ' for', ' the']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' a', ' in', ' to', ' the', ' (', ' that', ' of']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' to', '-', ' or', ' in', ' for', ' of']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' of', ' (', '-', '.', '\n', '/', ' with', ' or']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' of', ' or', ' to', '\n', '-']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', '.', '-', ' (', ' or', ' of', '/', '\n', ' to']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' (', ' and', '.', '-', ' in', ' to', '\n', ' -', ' for']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' of', ' and', ' (', ' to', ' in', ' with', '\n', '.', ' for']
# ---------
# LAYER:  blocks.3.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' in', ' (', ' of', ' to', ' that', ' [', ':']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' or', '.', ' in', '-', ' the', '\n', ' to']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['*', '–', '|', ',', ' *', '-', ' of', '?', ' another', ' the']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', ' (', '.', ' to', '-', ' in', '\n', ' -', ' or']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '-', ' of', ' or', ' in', '.', ' to', ' with', ' (']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '\n', ' of', ' the', ' in', ' (', ' to', '.', ' as']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' of', ' (', ' realm', ' before', ' form', '\n', ' that']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', '-', ' in', ' to', ' or', '/', ' the']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' the', '-', ' that', ' of', ' for']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['\x04', '\x12', '\x1b', '\x07', 'InstoreAndOnline', '\x00', '\x7f', ' サーティ', '\x0f', '�']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' in', ' (', ' to', '\n', ' on', ' of', ' the']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['\n', ',', '.', ' (', ' in', ' and', ' to', '/', '-', ' by']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' or', '.', ' in', ' to', ' of', '-', ' the']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' of', ' to', '\n', ' in', ' the', ' a']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' in', '.', ' to', '-', ' for', ' of', ' (', ' or']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', '.', ' (', '-', ' in', ' of', ' to', ' for', ' the']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' of', ' and', ' (', ' in', ' to', '-', '\n', '.', ' on']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' [', '.', ' in', ' to', ' (', ' for', ' of', ' the']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' of', ' in', ' to', '.', ' with', '-', ' for']
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' of', ' &', ' the', ' in', '/', "'"]
# ---------
# LAYER:  blocks.4.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', '-', ' to', ' in', ' of', '\n', ' from']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' of', ' to', '\n', ' the', ' at']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' to', ' (', ' of', ' that', ' in', ' on', ' -']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', '\n', ' in', ' to', ' of', ' the', ' or']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', '\n', ' in', ' to', '-', ' for', ' at']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', '.', ' in', ' to', '-', ' with', ' as', ' for', ' of']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', '.', ' to', ' (', ' and', ' of', '\n', ':', ' in', ' the']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['rency', ' Archdemon', ' {*', 'eyes', ' Deliver', 'hement', '�', 'mble', 'oshenko', '\n\xa0']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', '-', "'s", '.', ' in', ' or', ' (', '/', ' --']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' a', '.', ' the', '--', ' (', ' in', ' of', ' to']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' of', '.', '\n', ' in', ' to', ':', ' the']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' in', '.', '-', ' to', ' for', ' with', ' or']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' to', ' in', ' [', '\n', ' of', ' on']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' in', '-', ' of', ' with', ' from', ' for', ' on']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' (', ' and', ' or', '\n', '.', ' of', ' with', ' that', ' to']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', '‑', '-', '–', ':(', ' of', ' ―', '*', '(', ' additionally']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ':', ' of', ' in', ' to', '-', ' for']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' of', ' in', ' the', '.', '-', '\n', ' to']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', '.', ' and', ' to', ' in', ' of', '\n', ' for', ' (', ' that']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' in', ' (', ' of', '-', ' to', ' for', ' or']
# ---------
# LAYER:  blocks.5.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', ' to', '.', ' at', ' or', ' of', ' on', ' (', ' in']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', '-', ' in', ' to', ' for', ' of', '\n']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '-', ' of', ' in', '.', ' to', ' (', ' that', ' with']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '-', ':', '.', '/', '\n', ' in', ' -']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['edIn', '�醒', 'jri', ' Peb', ' Nanto', 'ngth', 'mble', 'ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ', ' Seym', '/_']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', '-', ' (', ' in', ' to', ' of', ' for', ' or']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' to', '.', ' in', ' of', ' the', ' (', ' for', ' at']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' to', ' in', '.', ' of', '-', ' for', ' the']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' in', ' to', '.', ' (', ' of', '\n', ' or', ' on']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' to', ' the', ' a', ' in', ' and', ' for', ' at', '.', ' (']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', '\n', '-', ' (', ',', ' in', ' or', '/', ' with', '(']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' to', '\n', ' in', ' the', '-', ' of']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', '.', ' of', ' to', ' (', ' for', ' that', ' with', ' in']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', '-', ' in', ' or', ' to', ' of', ' the']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', '-', ' (', '.', "'s", '\n', '/', ' in', ' of']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' in', '.', ' to', ' (', ' or', '-', ' the', ' that']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' of', ' a', ' to', ' [', ' (', '.', ' in', ' the']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' (', ' and', '.', ' in', ':', ' to', ' or', ' of', '-']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' to', ' of', ' or', '-', ' in', '/', ' (']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', '-', ' to', ' in', '/', '\n', ' of']
# ---------
# LAYER:  blocks.6.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', '.', ',', '-', ' (', ' in', ' to', '\n', ' of', ':']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' a', ' of', ' the', ' in', ' and', ' (', ' to', ' that', ' at']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' of', ' to', '\n', ' with', ' the']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['.', ',', ' and', '\n', ':', " ('", ' of', ' (', ' to', ';']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', '-', ' in', ' (', ' to', ' for', ' on', ' or']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', '-', ' to', '/', ' or', ' the', '\n']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['.�', ' ([', '..................', ' (<', " ('", ',', '.', ':(', ' &', '................................']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' against', ' battle', ' battles', ' fought', ' Fight', ' unsuccessfully', ' Battles', ' combat', ' fight', ' battled']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '\n', ':', ' of', '.', '-', ' in', ' to']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', '-', ' in', ' to', ':', '\n', ' or']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', '-', ' (', ' to', ' in', ' of', ':', ' the']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' of', ' the', '-', ' as']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' in', '.', ' to', '-', ' or', ' the', ' of']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' of', ' to', ' for', ' [', ' with']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', '-', ' of', ':', ' to', ' or']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' of', '.', '-', ' (', ' the', '\n', ' to', ' or']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' of', ' (', '-', '.', ' or', ' that', ' to', '/']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' or', ' to', ' in', ' for', '\n', ' of']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' in', ' of', ' to', ' (', ' the', '-', ' with', '.']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' to', '-', ' in', ' of', '\n', ' for']
# ---------
# LAYER:  blocks.7.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' in', ' to', ' (', ' of', ' or', ' the', ' for']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', ' of', ' the', '\n', '-']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', '-', ' in', ' (', ' of', ' to', ' for', ' from']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', ' or', ' of', ' the', '\n']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' in', '.', ' of', '-', ' to', ' (', ' for', ' with']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' in', ' to', ' the', ' of', ' that', '.', ' a']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', '.', ' and', ' (', '\n', ' in', ':', ' that', ' the', ' to']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' in', '-', '.', '\n', ' at', ' of', ' to']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' of', '-', ' (', '.', ' to', ' in', ' or', ' that']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' of', ' in', ' to', ':', '-', '\n']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '-', ' of', ' (', ' in', ' to', ' the', '.', ' with']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', '\n', '-', ' of', ' or', ':', ' to']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' in', ' (', ' to', ' of', ' or', ' for', '-']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' (', ' and', '.', '-', ' to', '\n', ' of', ' for', ' or']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' the', ' or', ' of', ' in', ' on', ' to']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' the', ' a', ' of', ' or']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', '\n', ' of', ' or', ' the']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' in', ' (', ' with', '.', ' during', ' at', ' before', ' while']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' (+', '.', ';', '\n', ':', '-,', ' and', ' (', ' (>']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' of', '-', ' to', ':', '\n']
# ---------
# LAYER:  blocks.8.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' or', '-', ' of', ' to', ' the']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', ' of', ' the', ' or', ' for']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' for', '-', ' on', ' of']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' of', '-', ':', ' in', ' to', '\n']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', '-', '\n', ' or', ' of', ' to', ' in']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' with', ' for', ' of', '\n', ':']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', '-', ' to', ' of', ':', ' the']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' to', '.', ' in', ' (', ' of', '-', ' the', ' for']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' to', ' in', '\n', ' of', ':', ' for']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' to', ' in', '-', ' of', ' or', '\n']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' in', '.', ' (', ' to', ' the', ' of', '-', ' for']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' or', ' to', '/', '-', ' in', '\n']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' to', ' (', '-', ' of', ' in', ' for', ':']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' to', ' in', ' of', ' the', '\n', ' for']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' of', '-', ' or', '\n', ' to']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' to', ' as', ' or', ' the', '.', ' in', ' that']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', ' (', ' or', '.', ' with', ' in', ' of', ' to', ' for']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' ever', ' EVER', ',', '.', ' in', ' to', ' and', ' (', ';', ' on']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' of', '-', ' (', '.', ' in', ' with', ' -', ':']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' to', ' in', ' of', '-', ' the', ' or']
# ---------
# LAYER:  blocks.9.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', '.', ' to', '-', ' (', '/', ' the', ' of', '\n']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', '-', ' of', ' or', ' for', ' with']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' of', ' to', ' in', ' or', '-', ' the']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', '-', ' of', ' to', ' or', ' on']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' of', ' to', ' in', '-', '\n', ' for']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', ' of', '-', ' the', ' or']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' to', ' in', ' of', '-', ' for', ' or']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' or', '-', '.', ' to', ' for', ' with', '\n']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' the', ' in', ' of', ' to', '-', ' on', ':']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ':', ' in', '-', ' with', '.', ' at', ' for']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', '.', ' (', ' in', ' to', '-', ' the', ' of', ' for']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' or', ' in', ' to', ' of', ' the', '-']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' in', '.', ' to', ' the', ' (', ' of', '\n', ' a']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' to', ' in', '\n', ':', ' or', ' for']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', '-', '.', ' for', ' (', ' to', ' as', ' [', ' of']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' to', ' (', '-', '.', ' of', ' in', '/', ' the']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', '-', '\n', ' or', ' in', ' to', ' the']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' to', ' (', ' in', ' of', ' or', ' that', ' at']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' of', '\n', '-', ' the']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', ' of', '-', ' or', '\n']
# ---------
# LAYER:  blocks.10.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' in', ' (', ' to', ' of', '-', ' the', '\n']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', '\n', ' in', ' of', ' the', ' to', '-']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' to', ' (', ' in', ' for', ' the', '\n', ' of']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' to', ' for', ' or', '\n', ' with', ' in']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' to', ' in', '-', ' of', ' or', ' for']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' of', ' in', ' to', ' for', '-', ' the', '.']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', ' (', ' to', '-', '.', ' in', ' of', ' or', ' the']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' of', ' in', ' to', '-', '\n', ' or']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' of', ' in', ' to', ' the', '-', ':']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' to', '.', ' for', ' as', ' or', ' in', ':']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' &', '.', ' of', ' (', ' in', ' or', ' to', ' -']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', '.', '-', ' and', ' with', ' in', ' of', '...', ' (', '(']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', '\n', ' in', ' (', ' the', ' to', ' of', ':']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' of', ' to', ':', '\n', ' the']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' to', ' in', ' of', ' or', ' the', '\n']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', '-', '\n', ' of', ' or']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', '-', '\n', ' the', ' of']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', ' or', '.', ' to', ' in', '\n', ' of', '-']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' against', ' [', ' (', ' with', '.', '\n', ' over', ' from']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', '-', ' of', ' or', '\n']
# ---------
# LAYER:  blocks.11.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', ' the', ' or', '-', ' of']
# ---------
# LAYER:  blocks.12.attn.hook_result | HEAD:  0
# ...
# [',', ' ("', ' "', ' and', ' (', ' at', ' the', ' in', ' of', ' to']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' Hist', ' History', ' historians', ' historical', ' historian', ' Historical', ' history', ' Confederate', ' FDR', ' 1861']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' …', '…', ' (', ' in', ' to', ' ...', ' the', '.']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', '.', ' and', ' (', ' the', '\n', '-', ' of', ':', ' a']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', '.', ' in', ' to', ' the', ' of', '-', ' or', ' for']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['\n', ',', 'Advertisement', ' and', ' (', '-', '/', '.', ' to', '\n\n']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' to', ' of', ' in', '-', ' the', ' that']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', '-', '.', ' and', ' (', ' of', ' to', ' –', '\n', ':']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', ' of', '-', '\n', ' the']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', '-', ' to', ' of', '\n', ' in', ':']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' of', '-', ' for', '\n']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', '-', ' of', '\n', ' or']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', '-', ' the', ' of', ' for']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' whilst', ' (£', ' Nasa', ' util', ' (', '.', ' organisation', ' -']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' in', ',', ' on', ' and', ' to', ' at', ' from', ' with', ' (', '.']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' Tail', '\n\n', ' Rosenberg', ' tails', ' perm', ' 608', ' Pru', ' SEN', ' Turbo', ' tail']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' of', '-', ' or', ' for']
# ---------
# LAYER:  blocks.32.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' to', ' in', ' (', '-', ' of', ' the', ' or']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' 2', '.', ' 5', ' 12', ' 4', ' (', ' 3', ' in']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' to', ' in', ' for', ' or', '-', '\n']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' e', ' and', '-', ' (', ' to', ' of', ' the', ' in', '.']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' in', ' the', ' (', ' [', '.', ' to', ' that', ' a']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', ' of', ' the', '-', ' or']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' to', ' in', '-', ' of', ' the', ' or']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' to', ' in', '-', '\n', ' of', ' or']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' (', '.', ' the', ' and', ' in', '-', ' to', ' of', ' -']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' battles', ' battle', ' wars', 'battle', ' fighting', ' war', ' fought', ' Battle', ' fight', ' fights']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' of', '-', ' or', ' for']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' of', ' or', '\n', ' for']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' Izan', ' --------------------', ' ILCS', 'andem', 'ゼウス', ' Divide', 'ieft', ' FML', '................', ' Skydragon']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' United', 'United', ',', ' —', '—', '–', ';', ',[', '.[', ' and']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' of', ' in', ' to', ' at', ' for', ' the']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' of', '-', ' the', ' or']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', ' or', ' of', '-', ' the']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' Fidel', ' carn', ' Renault', ' Polo', ' Cuba', ' cav', ' Fulton', ' Corona', ' Cuban', ' Russia']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' Eucl', ' Ny', ',', ' (', ' Finder', ' Poll', ' and', '-', ' magnet', ' Einstein']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '\n', ' (', '.', ' in', ' to', ' of', ' the', '-']
# ---------
# LAYER:  blocks.33.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' to', ' in', ' of', '-', ' or', ' the']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' of', ' and', '.', ' (', ' in', ' to', '\n', '-', ' the']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', '-', ' in', ' to', ' of', '\n', ' the']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['-', ',', ' Total', ' or', ' and', ' total', ' on', ' in', ' (', " ('"]
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', '-', ' of', '\n', ' for']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' of', ' for', '-', ' at']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' f', ' fe', ' correl', ' com', ' subdiv', ' Bad', ' trough', ' Us', ' Ambro', ' Fe']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' in', ' to', ' of', '-', ' the', ' or']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', '-', ' or', ' to', ' with', ':', ' of']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' DISTR', ' DRAG', ' LET', ' EVER', ' THESE', ' WAY', ' FIRST', ' PRES', ' CONTIN', ' PROG']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' of', '-', ':', ' or']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' —', ' Ing', ' Karl', ' stra', ' reserv', ' instead', ' Wik', ' Jer', ' the']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' Punk', ' Izan', ' Gy', ' Chaos', ' Rebell', ' Skydragon', ' Mayhem', ' Celest', ' Kik', ' Swe']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', '-', ' of', '\n', ' for']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' to', ' in', ' of', '-', '/', ' for']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' Rune', ' Morrow', ' Sora', ' Frey', ' (', ' to', ' in']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' here', ',', ' and', '-', '\n', '.', ' in', '/', ' to', ' for']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', '-', '\n', ' in', ' the', ' as', ' to']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', '.', ' and', ' (', ' in', ' to', ' or', ' of', '-', ' the']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', ' to', ' or', '\n', '-', ' of']
# ---------
# LAYER:  blocks.34.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', ' in', '-', ' to', ' of', '\n', ' the']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  0
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' the', ' in', ' comp', ' disc', ' for', '.', ' to', ' on']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  1
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' (', ' and', ' in', ' to', '(', ' of', '\n', ' the', '.']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  2
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['iard', 'ilyn', 'achine', 'otta', ' Kund', ' Wander', ' Pag', 'ocene', ' Krish', 'rigan']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  3
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['\xad', ',', ' and', '-', ' Priority', ' in', '.', ' tax', ' Government', ' to']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  4
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['\n', ':', ',', ' and', ' (', '.', ' or', ' in', ' to', ' as']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  5
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' Angelo', ' Fal', ' Kh', ' Sang', ' Imam', ' Giovanni', ' Chung', ' Spring', ' Joe', ' Dip']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  6
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' Resp', ' Sierra', ' Silicon', ' Serious', ' Reuters', ' Getty', ' SIL', ' Jobs', ' Kern', ' African']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  7
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' (', '-', ' to', ' in', ' or', ' of', ' the']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  8
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' United', ' and', ',', '.', ' in', ' (', '-', ' U', ' to', ' First']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  9
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' &', ',', ' (&', ' (', ' /', '\n', ' 1', ':', '.', '/']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  10
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' (', '.', ' to', ' in', ' of', ' for', '\n', ' or']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  11
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' &', '\n', ' and', ' Get', 'Go', ' (', '\n\n', ' Go', '.']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  12
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' (', ',', ' ([', ' and', ' ®', ' *', 'û', ' -', '.', ' Frey']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  13
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' Fate', ' Helm', ',', ' Otto', ' Wolfe', ' H', ' Wright', ' Dud', ' and', ' Everett']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  14
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', ' in', ' the', ' of', ' to', ' a', ' with', ' at', ' [']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  15
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' (', ',', ' and', '.', '-', '\n', '?', '...', ' in', ' -']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  16
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', ' in', ' "', ' on', ' to', '.', ' of', ' a', ' for']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  17
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' --------------------', ' �', ' &', ' Lib', ' GU', ' #', ' ---', ' ***', ' both', ' :)']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  18
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['...', '-', '_', ',', '>', ' (', '\n', '…', '..', ' and']
# ---------
# LAYER:  blocks.35.attn.hook_result | HEAD:  19
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', ' and', '.', ' to', ' (', '-', ' or', ' in', ' of', ' the']
# ---------

# %%
prompt = "The first president of the United States fought in the"
head_latent_space_projector(gpt2_large, prompt, 10, 20, aggregate_heads=True, intermediate_tokens=True)
# Out:
# LAYER:  blocks.0.hook_attn_out
# PROMPT:  <|endoftext|>
# ['<|endoftext|>', '\n', ' Copyright', '(', '\n\n', ' […]', '\xa0', '*', ' May', ',']
# ---------
# LAYER:  blocks.0.hook_attn_out
# PROMPT:  <|endoftext|>The
# [',', ' the', '.', ' and', '\n', '(', ' (', ' in', ' just', ' "']
# ---------
# LAYER:  blocks.0.hook_attn_out
# PROMPT:  <|endoftext|>The first
# [',', ' first', ' to', ' (', ' and', ' in', '-', ' last', '.', ' a']
# ---------
# LAYER:  blocks.0.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [' president', ' President', ',', ' presidential', '.', ' and', ' chairman', ' who', "'s", ' in']
# ---------
# LAYER:  blocks.0.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [',', ' the', ' and', '.', ' (', ' in', ' of', ' to', ' that', ':']
# ---------
# LAYER:  blocks.0.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [',', ' the', '.', ' (', ' and', ' in', ' "', ' to', ':', ' of']
# ---------
# LAYER:  blocks.0.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# [' United', ' U', ' American', ' New', ' International', ' Un', ' government', ' National', ' World', ' States']
# ---------
# LAYER:  blocks.0.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States
# [' States', ' United', ',', ' American', ' U', ' State', ' states', '.', '-', "'s"]
# ---------
# LAYER:  blocks.0.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [' fought', ' battles', ' against', ' fights', ' fighting', ' waged', ',', ' battled', ' battling', ' fight']
# ---------
# LAYER:  blocks.0.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [',', ' the', '.', ' (', '-', ' in', ' and', ' to', ' that', ' of']
# ---------
# LAYER:  blocks.0.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [',', '.', ' the', ' (', ' in', ' and', ':', ' United', '-', ' "']
# ---------
# LAYER:  blocks.1.hook_attn_out
# PROMPT:  <|endoftext|>
# [' Editor', ' and', ' C', ' Paul', ' I', ' Twitter', ' following', ':', ' |', ',']
# ---------
# LAYER:  blocks.1.hook_attn_out
# PROMPT:  <|endoftext|>The
# [',', ' following', ' and', ' I', ' "', ' Twitter', ' on', ' in', ' Paul', ':']
# ---------
# LAYER:  blocks.1.hook_attn_out
# PROMPT:  <|endoftext|>The first
# [' I', ' of', ' response', ' members', ' and', ' Reddit', ' Apple', ' Facebook', ' two', ' Twitter']
# ---------
# LAYER:  blocks.1.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [' I', ' and', ' Wednesday', ',', ' of', ' rookie', ' Thursday', ' on', ' opening', ' next']
# ---------
# LAYER:  blocks.1.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [' Nov', ' the', ' a', ' Wednesday', ' also', ' Paul', ' members', ' two', ' chairman', ' 18']
# ---------
# LAYER:  blocks.1.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [',', 

# ---------
# LAYER:  blocks.17.hook_attn_out
# PROMPT:  <|endoftext|>
# [',', ' and', '.', ' in', ' (', ' to', ' of', ' or', '\n', ' the']
# ---------
# LAYER:  blocks.17.hook_attn_out
# PROMPT:  <|endoftext|>The
# [',', ' and', '.', ' (', ' in', ' to', '\n', ' of', ' the', ' or']
# ---------
# LAYER:  blocks.17.hook_attn_out
# PROMPT:  <|endoftext|>The first
# [',', ' and', ' (', ' in', '.', ' the', ' of', ' is', ' –', "'s"]
# ---------
# LAYER:  blocks.17.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [' dedicated', ' debuted', ' came', '-', ' rose', ' Battle', ' changes', ' rolled', ' (', ' of']
# ---------
# LAYER:  blocks.17.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [' born', ' rose', ' came', ' rolled', ' to', ' crowned', ' ever', ' finished', ' of', ' (']
# ---------
# LAYER:  blocks.17.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [',', ' of', ' Batt', ' named', ' born', ' called', ' (', ' Trans', ':', ' Defense']
# ---------
# LAYER:  blocks.17.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# [' named', ' Ember', ' independent', ' called', ' specializing', ' apprentices', ' Enterprises', ' Institute', ' Guild', ' glob']
# ---------
# LAYER:  blocks.17.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States
# [' called', ' born', ' named', ' Adolf', ' apprentice', ' Gerald', ' Emmy', ' ray', ' pen', ' Someone']
# ---------
# LAYER:  blocks.17.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [',...', ' —', ' and', ' ,', ' whose', ',', ' of', ' in', 'warm', '—']
# ---------
# LAYER:  blocks.17.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [' wars', ' vs', 'warm', ' polyg', ' battles', ' exclusively', ' during', ' against', ' waged', ' alone']
# ---------
# LAYER:  blocks.17.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' wars', ' battles', ' battle', ' battled', ' battleground', 'battle', ' Batt', ' Wars', ' war', ' fought']
# ---------
# LAYER:  blocks.18.hook_attn_out
# PROMPT:  <|endoftext|>
# [',', ' and', ' in', ' (', '.', ' to', ' or', ' of', '\n', ' the']
# ---------
# LAYER:  blocks.18.hook_attn_out
# PROMPT:  <|endoftext|>The
# [',', ' and', ' in', ' (', ' of', ' to', ' the', '\n', '.', ' for']
# ---------
# LAYER:  blocks.18.hook_attn_out
# PROMPT:  <|endoftext|>The first
# [' and', ',', ' of', ' in', ' (', ' to', ' the', '-', ' or', '\n']
# ---------
# LAYER:  blocks.18.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [' is', ',', ' of', ' was', ' began', ' and', '-', ' first', ' from', ' came']
# ---------
# LAYER:  blocks.18.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [' born', ' XVI', ' reborn', ' apprentice', ' ever', ' Britann', ' Ever', '-', ' eight', ' of']
# ---------
# LAYER:  blocks.18.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [' formed', ' atom', ' Institute', ' organisation', ' Association', ' association', ' organization', ' XI', '‑', ' union']
# ---------
# LAYER:  blocks.18.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# ['ocracy', ' Confederation', ' Mult', ' federation', ' Foundation', ' Association', ' formed', ' colonies', ' merged', ' Sovereign']
# ---------
# LAYER:  blocks.18.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States
# [' EVER', ' Britann', ' Grand', ' Mult', ' belongs', ' Slave', ' Period', ' came', ' born', ' oldest']
# ---------
# LAYER:  blocks.18.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [' appoint', ' cabinet', ' impeachment', ' inaug', ' appointing', ' Cabinet', ' Himself', ' speech', ' Jr', ' veto']
# ---------
# LAYER:  blocks.18.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [' arming', ' aut', ' slave', ' accessory', ' slaves', ' explicitly', ' arm', ' praising', ' ALL', ' lavish']
# ---------
# LAYER:  blocks.18.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' arming', ' arm', ' slave', ' armed', ' instrument', ' ration', ' violent', ' extensively', ' and', ' slaves']
# ---------
# LAYER:  blocks.19.hook_attn_out
# PROMPT:  <|endoftext|>
# [',', ' and', '.', ' (', ' of', ' to', ' in', '\n', ' or', ' the']
# ---------
# LAYER:  blocks.19.hook_attn_out
# PROMPT:  <|endoftext|>The
# [',', ' (', ' and', '\n', '.', '...', ' in', ' for', ' of', '-']
# ---------
# LAYER:  blocks.19.hook_attn_out
# PROMPT:  <|endoftext|>The first
# [' (', ',', '\n', ' and', ' in', '.', ' of', ' or', ' for', '-']
# ---------
# LAYER:  blocks.19.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [',', ' and', '\n', '.', ' in', ' of', ' (', ' the', ' to', ' or']
# ---------
# LAYER:  blocks.19.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [',', ' and', '.', ' the', ' in', '\n', ' a', ' of', ' to', ' –']
# ---------
# LAYER:  blocks.19.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [',', ' and', ' –', '.', '\n', ' in', '-', ' the', ' (', ' of']
# ---------
# LAYER:  blocks.19.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# [',', ' and', ' –', '.', ' today', ' [', ' in', ' the', '-', '\n']
# ---------
# LAYER:  blocks.19.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States
# [',', '\n', ' and', ' [', ' (', ' of', ' .', '.', ' in', ' to']
# ---------
# LAYER:  blocks.19.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [' the', '\n', ',', ' of', '.', ' and', ' in', '-', ' a', ' today']
# ---------
# LAYER:  blocks.19.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [' Hulk', ' MMA', ' UFC', ' fighter', ' Battles', ' fighters', ' McCain', ' wrestling', ' armed', ' Combat']
# ---------
# LAYER:  blocks.19.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' America', ' Battle', ' military', ' Batt', ' undefeated', ' Battles', ' armed', ' armor', ' fighters', ' combat']
# ---------
# LAYER:  blocks.20.hook_attn_out
# PROMPT:  <|endoftext|>
# [',', ' and', '.', '\n', ' of', ' (', ' in', ' the', ' to', ' or']
# ---------
# LAYER:  blocks.20.hook_attn_out
# PROMPT:  <|endoftext|>The
# [',', ' and', 

# ---------
# LAYER:  blocks.23.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [' men', ' young', ' women', ' a', ' the', ' chief', ' democracy', ' president', ' revolutionaries', ',']
# ---------
# LAYER:  blocks.23.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [',', ' a', ' the', ' to', ' in', ' and', ' school', '-', ' as', ' (']
# ---------
# LAYER:  blocks.23.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# [',', ' --', ' (', '-', '.', ' was', ' a', ' and', ' -', ' said']
# ---------
# LAYER:  blocks.23.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States
# [' since', ' modern', ' Jefferson', ' presidents', ' postwar', ' Negro', ' historians', ' electors', ' America', ' negro']
# ---------
# LAYER:  blocks.23.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [' negro', ' Negro', ' liberty', ' wars', ' war', ' secession', ' slavery', ' England', ' Britain', ' British']
# ---------
# LAYER:  blocks.23.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [' partisan', ' racially', ' wrestling', ' secession', ' war', ' Quincy', ' Christian', ' feud', ' Catholic', ' religious']
# ---------
# LAYER:  blocks.23.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' prison', ' Quincy', ' colonial', ' and', ' martial', ' war', ' the', ',', ' slave', ' school']
# ---------
# LAYER:  blocks.24.hook_attn_out
# PROMPT:  <|endoftext|>
# [',', ' and', ' in', '.', ' (', ' the', '\n', ' to', ' of', ' a']
# ---------
# LAYER:  blocks.24.hook_attn_out
# PROMPT:  <|endoftext|>The
# [',', '\n', ' "', ' and', ' the', ' in', ' a', ' to', ' on', " '"]
# ---------
# LAYER:  blocks.24.hook_attn_out
# PROMPT:  <|endoftext|>The first
# [',', ' and', ' "', ' in', '\n', ' of', ' the', ' a', ' to', ' on']
# ---------
# LAYER:  blocks.24.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [' came', ' was', ' happened', ' to', ' recently', ' has', ' dawn', ' began', ' arrived', ' spontaneously']
# ---------
# LAYER:  blocks.24.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [' ever', ' in', ' truly', ' a', ' without', ' dared', ' foreign', ' so', ' this', ' even']
# ---------
# LAYER:  blocks.24.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [' ever', ' formally', ' AMA', ' Association', ' organized', ' revolution', ' philanthrop', ' record', ' formal', ' group']
# ---------
# LAYER:  blocks.24.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# ...
# [' American', ' US', ' of', ',', ' Truman', ' America', ' Americans', ' Congress', ' Cuban', ' Puerto']
# ---------
# LAYER:  blocks.27.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [' his', ' America', ' American', ' he', ' Americans', ' decades', ' himself', ' Congress', ' US', ' the']
# ---------
# LAYER:  blocks.27.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [' America', ' American', ' Americans', ' his', ' decades', ' Congress', ' 1940', ' Native', ' 1960', ' he']
# ---------
# LAYER:  blocks.27.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' 1940', ' America', ' decades', ' American', ' 1960', ' 1950', ' 1930', ' Americans', ' Congress', ' 1941']
# ---------
# LAYER:  blocks.28.hook_attn_out
# PROMPT:  <|endoftext|>
# [',', ' and', '.', ' in', ' the', ' (', ' to', ' of', '\n', ' a']
# ---------
# LAYER:  blocks.28.hook_attn_out
# PROMPT:  <|endoftext|>The
# [',', ' and', '.', ' in', ' the', ' (', ' to', '\n', ' a', '-']
# ---------
# LAYER:  blocks.28.hook_attn_out
# PROMPT:  <|endoftext|>The first
# [',', ' and', ' in', '.', ' to', ' (', ' of', ' the', ';', '-']
# ---------
# LAYER:  blocks.28.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [',', ' and', '.', ' in', ' the', ' (', ' a', '\n', '-', ' for']
# ---------
# LAYER:  blocks.28.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [',', ' and', ' in', '.', ' the', '\n', ' (', ' a', ' of', ' to']
# ---------
# LAYER:  blocks.28.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [',', ' and', ' in', ' the', '.', ' (', '\n', '-', ' to', ' a']
# ---------
# LAYER:  blocks.28.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# [',', ' and', '.', ' (', ' in', ' the', ' to', '-', '\n', ' a']
# ---------
# LAYER:  blocks.28.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States
# [',', ' and', '.', ' the', ' in', ' a', ' (', ' to', ' at', '\n']
# ---------
# LAYER:  blocks.28.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [' war', ',', ' battle', ' battles', ' and', '.', ' Battle', ' the', ' in', ' fight']
# ---------
# LAYER:  blocks.28.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [' war', ' battlefield', ' wartime', ' soldier', ' War', ' warfare', ' soldiers', ' Battle', ' infantry', ' artillery']
# ---------
# LAYER:  blocks.28.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' war', ' wartime', ' battlefield', ' War', ' Battle', ' warfare', ' soldier', ' wars', ' artillery', ' soldiers']
# ---------
# LAYER:  blocks.29.hook_attn_out
# PROMPT:  <|endoftext|>
# [',', ' and', '.', ' the', ' (', ' in', ' to', ' a', '\n', ' of']
# ---------
# LAYER:  blocks.29.hook_attn_out
# PROMPT:  <|endoftext|>The
# [',', ' and', ' in', ' to', ' the', ' on', '.', ' (', '-', ' a']
# ---------
# LAYER:  blocks.29.hook_attn_out
# PROMPT:  <|endoftext|>The first
# [',', ' and', ' in', ' (', ' the', ' to', '.', ' a', '-', ' on']
# ---------
# LAYER:  blocks.29.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [',', ' and', '-', ' in', ' (', ' the', ' to', ' on', '.', ' a']
# ---------
# LAYER:  blocks.29.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [' and', ',', ' in', ' a', ' (', '-', ' the', '.', ' to', ' of']
# ---------
# LAYER:  blocks.29.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [' and', ',', '-', ' (', ' in', '.', ' a', ' "', ' the', ' to']
# ---------
# LAYER:  blocks.29.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# [',', ' and', ' (', '-', ' in', '.', ' a', ' the', ' to', ' of']
# ---------
# LAYER:  blocks.29.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States
# [',', ' and', ' –', ' in', '-', ' (', ' the', ' on', ' to', '.']
# ---------
# LAYER:  blocks.29.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [',', ' and', ' (', ' in', ' the', '-', ' a', ' to', ' —', ' "']
# ---------
# LAYER:  blocks.29.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [',', ' and', ' (', ' in', '-', ' the', ' a', ' to', '.', ' "']
# ---------
# LAYER:  blocks.29.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' and', ',', ' (', ' a', '-', ' in', ' the', ' "', ' to', '.']
# ---------
# LAYER:  blocks.30.hook_attn_out
# PROMPT:  <|endoftext|>
# [',', ' and', '.', ' (', ' in', ' the', ' to', ' of', '\n', ' a']
# ---------
# LAYER:  blocks.30.hook_attn_out
# PROMPT:  <|endoftext|>The
# [',', ' and', ' (', '.', ' in', ' the', ' to', '\n', ' of', '-']
# ---------
# LAYER:  blocks.30.hook_attn_out
# PROMPT:  <|endoftext|>The first
# [',', ' and', ' (', '.', ' the', ' in', '-', '\n', ' of', ' to']
# ---------
# LAYER:  blocks.30.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [',', ' and', '.', ' (', ' in', ' the', '\n', ' of', ' to', '-']
# ---------
# LAYER:  blocks.30.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [' Arizona', ' and', ' Hawaii', ',', ' Alaska', ' Utah', ' The', ' Calgary', ' White', ' South']
# ---------
# LAYER:  blocks.30.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [' political', ' presidential', ' President', ' Presidential', ' caucus', ' electoral', ' election', ' elected', ' vote', ' White']
# ---------
# LAYER:  blocks.30.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# [' membership', ' and', ',', ' Alberta', ' Mexican', ' Canada', ' Arizona', ' Chicago', ' Hawaii', ' Membership']
# ---------
# LAYER:  blocks.30.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States
# [' political', ' presidential', ' Washington', ',', ' election', ' Presidential', ' and', ' elected', ' Senate', ' Congress']
# ---------
# LAYER:  blocks.30.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [',', ' and', ' (', ' in', '.', ' the', '-', ' to', ' or', ' on']
# ---------
# LAYER:  blocks.30.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [',', ' and', '.', '-', ' in', ' the', ' "', ' to', ' or', ' (']
# ---------
# LAYER:  blocks.30.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' military', ' war', ' Army', ' soldiers', ' Military', ' Navy', ' soldier', ' troops', ' battlefield', ' combat']
# ---------
# LAYER:  blocks.31.hook_attn_out
# PROMPT:  <|endoftext|>
# [',', ' and', ' the', ' (', '\n', '.', ' in', ' a', ' to', ' of']
# ---------
# LAYER:  blocks.31.hook_attn_out
# PROMPT:  <|endoftext|>The
# [',', ' and', ' in', ' (', ' the', ' a', ' to', ' or', '\n', ' of']
# ---------
# LAYER:  blocks.31.hook_attn_out
# PROMPT:  <|endoftext|>The first
# [',', ' and', ' (', ' in', ' of', '.', ' to', ' the', ' a', '-']
# ---------
# LAYER:  blocks.31.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [',', ' in', ' and', ' (', ' on', ' to', ' of', ' that', '.', ' for']
# ---------
# LAYER:  blocks.31.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [',', ' (', ' and', ' in', ' the', ' a', '.', ' to', ' on', ' of']
# ---------
# LAYER:  blocks.31.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [' United', ' USA', ' "', ' (', ' U', ' New', ' America', ' Free', ',', ' American']
# ---------
# LAYER:  blocks.31.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# [' Democratic', ' Socialist', ' Workers', ' Democrats', ' workers', ' (', ' socialist', ' liberal', ' liberals', ' Communist']
# ---------
# LAYER:  blocks.31.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States
# [',', ' in', ' on', ' to', ' and', ' that', ' (', ' of', ' for', '.']
# ---------
# LAYER:  blocks.31.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [',', ' and', ' (', ' the', ' in', ' a', '.', ' to', '-', ' of']
# ---------
# LAYER:  blocks.31.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [',', ' and', ' (', '-', ' in', ' the', '.', ' a', ' as', ' to']
# ---------
# LAYER:  blocks.31.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' battles', ' war', ' wars', ' fights', ' battle', ' fight', ' duel', ',', ' Battles', ' War']
# ---------
# LAYER:  blocks.32.hook_attn_out
# PROMPT:  <|endoftext|>
# [',', ' and', '\n', '.', ' (', ' in', ' the', ' to', ':', ' for']
# ---------
# LAYER:  blocks.32.hook_attn_out
# PROMPT:  <|endoftext|>The
# [',', ' and', ' in', '\n', ' the', ' to', ' for', '.', ' at', ' a']
# ---------
# LAYER:  blocks.32.hook_attn_out
# PROMPT:  <|endoftext|>The first
# [',', ' and', ' in', ' to', '.', ' of', ' for', ' on', ' at', ' the']
# ---------
# LAYER:  blocks.32.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [' to', ' of', ' in', ',', ' and', ' was', 'to', ' To', ' is', ' who']
# ---------
# LAYER:  blocks.32.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [',', ' and', ' Trump', ' in', ' "', ' to', ' the', ' Donald', ' of', ' (']
# ---------
# LAYER:  blocks.32.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [',', ' and', ' "', ' to', ' in', ' Trump', '\n', ' Donald', ' of', ' (']
# ---------
# LAYER:  blocks.32.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# [',', ' and', ' in', ' for', '.', ' of', ':', ' to', '-', ' the']
# ---------
# LAYER:  blocks.32.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States
# [' to', 'to', ' To', 'To', ' under', ' who', ' whom', ' was', ' left', 'TO']
# ---------
# LAYER:  blocks.32.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [' history', ' historical', ' History', ' historian', ' historians', ' in', ',', ' Hist', ' "', ' and']
# ---------
# LAYER:  blocks.32.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [' history', ' historical', ' History', ' histories', ' historians', ' Confederate', ' historian', ' Hist', ' historically', ' Native']
# ---------
# LAYER:  blocks.32.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' historical', ' history', ' History', ' Native', ' Confederate', ' historian', ' historians', ' histories', ' Hist', ' Chero']
# ---------
# LAYER:  blocks.33.hook_attn_out
# PROMPT:  <|endoftext|>
# [',', '-', ' and', '.', ' the', ' (', ' in', '\n', ' a', ' to']
# ---------
# LAYER:  blocks.33.hook_attn_out
# PROMPT:  <|endoftext|>The
# [',', '.', ' the', ' and', ' (', ' in', ' to', '\n', ' a', ' -']
# ---------
# LAYER:  blocks.33.hook_attn_out
# PROMPT:  <|endoftext|>The first
# [',', ' (', ' the', ' and', ' in', ' a', '\n', ' to', '-', ' -']
# ---------
# LAYER:  blocks.33.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [',', ' and', ' (', ' in', ' the', ' "', ' to', '-', ' a', '\n']
# ---------
# LAYER:  blocks.33.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [',', ' (', ' in', ' and', ' the', '-', '\n', ' "', ' to', '.']
# ---------
# LAYER:  blocks.33.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [',', ' (', ' U', '\n', '.', ' the', ' [', '-', ' St', ' White']
# ---------
# LAYER:  blocks.33.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# [' U', ' S', ' South', ' Som', '\n', ' Coc', ' (', ' Fifa', ',', ' White']
# ---------
# LAYER:  blocks.33.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States
# [' calls', ' Lincoln', ' bin', ',', ' call', ' Bush', ' (', '\n', ' in', ' presidential']
# ---------
# LAYER:  blocks.33.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [',', ' in', ' and', ' the', ' (', ' to', ' a', ' "', '-', '\n']
# ---------
# LAYER:  blocks.33.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [' Tobacco', ' e', ',', ' block', ' law', ' segregated', ' black', ' tax', ' in', ' Pas']
# ---------
# LAYER:  blocks.33.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' Tobacco', ' segregated', ' Cuba', ' e', ' slavery', ' Fidel', ' battles', ' United', ' Confederate', ' Abraham']
# ---------
# LAYER:  blocks.34.hook_attn_out
# PROMPT:  <|endoftext|>
# [' now', ' because', ' hereafter', ' who', ' rushing', ' doing', 'zzo', ' just', ' when', '\u200e']
# ---------
# LAYER:  blocks.34.hook_attn_out
# PROMPT:  <|endoftext|>The
# [' and', ',', '-', ' in', ' that', ' the', ' on', ' of', '.', ':']
# ---------
# LAYER:  blocks.34.hook_attn_out
# PROMPT:  <|endoftext|>The first
# ['-', ' and', ',', ' the', ' in', ' (', " '", ' ', ' on', ' a']
# ---------
# LAYER:  blocks.34.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [',', '\u200e', ' (', ' and', ' Scan', ' of', '-', '(', '.', '\n']
# ---------
# LAYER:  blocks.34.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [',', ' and', '-', ' in', ' of', ' the', ' (', '.', '\n', ' on']
# ---------
# LAYER:  blocks.34.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [',', '-', ' and', ' the', ' in', ' of', ' a', ' (', ' World', ' T']
# ---------
# LAYER:  blocks.34.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# ['-', ' and', ',', ' [', '[', ' of', ' (', '\n', '.', ' Black']
# ---------
# LAYER:  blocks.34.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States
# [',', '\u200e', ' Bul', ' of', ' and', ' Bush', '.', ' [', ' in', ' Ll']
# ---------
# LAYER:  blocks.34.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [',', ' and', ' in', '-', ' of', ' the', ' that', '.', ' (', '\n']
# ---------
# LAYER:  blocks.34.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [',', ' here', ' and', ' the', ' in', ' of', ' no', '-', '\n', ' a']
# ---------
# LAYER:  blocks.34.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# [' Bad', ' f', ' Peck', ' Great', ' in', ',', ' Woo', ' civil', '!', ' feud']
# ---------
# LAYER:  blocks.35.hook_attn_out
# PROMPT:  <|endoftext|>
# ['\x0b', '\r', '龍�', '�', '�', '\x06', '\x04', '\x03', '\x1f', '\x1a']
# ---------
# LAYER:  blocks.35.hook_attn_out
# PROMPT:  <|endoftext|>The
# [' �', ' Witcher', ' Vikings', ' Spiel', ' Dodge', ' �', ' Broncos', ' Sparkle', ' DOD', ' Spartans']
# ---------
# LAYER:  blocks.35.hook_attn_out
# PROMPT:  <|endoftext|>The first
# [' Witcher', ' Big', ' LEGO', ' Vikings', ' iPhone', ' League', ' Fast', '-', ' Soccer', ' US']
# ---------
# LAYER:  blocks.35.hook_attn_out
# PROMPT:  <|endoftext|>The first president
# [' Swedish', ' Javascript', ' Virtual', ' virtual', ' Zoe', ' digital', ' Tinder', ' robotic', ' Donald', ' Turkish']
# ---------
# LAYER:  blocks.35.hook_attn_out
# PROMPT:  <|endoftext|>The first president of
# [' Oculus', ' Celtic', ' Kentucky', ' Zen', ' Polaris', ' Artemis', ' Sega', ' Ohio', ' LEGO', ' League']
# ---------
# LAYER:  blocks.35.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the
# [' Zen', ' Mé', ' Cron', ' Romania', ' Rome', ' Lith', ' Kentucky', ' League', ' IS', ' Corinth']
# ---------
# LAYER:  blocks.35.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United
# [' Association', ' Federation', ' World', ' \u200e', ' League', ' Organisation', ' Independent', ' Mé', ' […]', ' Wood']
# ---------
# LAYER:  blocks.35.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States
# [' virtual', ' Digital', ' Virtual', ' prem', ' digital', ' Light', ' light', ' app', ' Electronic', ' Stock']
# ---------
# LAYER:  blocks.35.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought
# [' United', '\n', '\u200e', ' Stand', ' U', '-', ' virtual', ' Supreme', ' HIT', ',']
# ---------
# LAYER:  blocks.35.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in
# [' Stand', ' Strategy', ' baseball', 'Fake', ' compromise', ' giant', ' (&', ' golf', ' Commit', ' MLB']
# ---------
# LAYER:  blocks.35.hook_attn_out
# PROMPT:  <|endoftext|>The first president of the United States fought in the
# ['Angelo', 'SIGN', ' Old', 'Story', ' NRA', ' pitched', ' compromise', ' Polk', ' wars', ' civil']
# ---------

# %% [markdown]
# # How do we inject memories at each layer?
#
# We can inject concepts into the residual stream by editing the outputs of the attention layers
#
# **How do we do this:**
#
# We project memories from vocabulary space into the pseudo-latent space of the model by applying the transpose of the unembedding matrix to the tokenized memory. We then add these transformed memories directly to the outputs of an attention layer.

# %%
# We define a residual stream patching hook
# We choose to act on the residual stream at the start of the layer, so we call it resid_pre
# The type annotations are a guide to the reader and are not necessary

#Args:
def memory_tweaker_hook(
    attn_out: Float[torch.Tensor, "num_tokens d_model"],
    hook: HookPoint, #name of layer where we inject memory
    extra_info: str, #the string that we tokenize and then inject into memory
    model: transformer_lens.HookedTransformer, #the model from which we get the unembedding matrix from
    vocab_size: int, #size of model vocabulary
    tweak_factor: float,
    #cache: transformer_lens.ActivationCache #this is the
) -> Float[torch.Tensor, "batch pos d_model"]:

    print("Hook point: ", hook.name)
    #tokenize string
    tok_extra_info = model.to_tokens(extra_info, prepend_bos=False)
    print(tok_extra_info)

    #transform tokens into one-hot vector
    extra_memory = torch.zeros(vocab_size).to(device)
    #TODO: need to put a one in the spot with all of the extra info tokens and mult by tweak factor
    for i in tok_extra_info:
      extra_memory[i] = 1

    #subtract bias, and apply transpose of unembeding matrix to tokenized string to get it into model's hidden dim
    #extra_memory = extra_memory - model.unembed.b_U
    extra_memory = einsum("d_vocab, d_vocab d_model-> d_model", extra_memory, model.W_U.T)

    #TODO think about how layer norm would imapct things

    #add the extra_info embedded in latent space to hook_attn_out
    attn_out = attn_out + extra_memory * tweak_factor


    #return this edited hook_attn_out
    return attn_out

# %%
# Use functools.partial to create a temporary hook function with the position fixed
temp_hook_fn = partial(memory_tweaker_hook,
                       extra_info="The president",
                       vocab_size=50257,
                       model=gpt2_small,
                       tweak_factor=3)

prompt = "The leader of the United States lives in the"
#Get original logits
logits = gpt2_small(prompt)

#Get patched Logits
layer  = 9
patched_logits = gpt2_small.run_with_hooks(prompt,
                          fwd_hooks=[
                                      ( utils.get_act_name("attn_out", layer),
                                      temp_hook_fn)
                                      ]
                          )
# Out:
# Hook point:  blocks.9.hook_attn_out
# tensor([[ 464, 1893]])

# %%
print("Edited Tokens")
topk_token_vals, topk_token_preds = torch.topk(logits, 70)
gpt2_small.to_string(topk_token_preds[0][-1])
# Out:
# Edited Tokens
# ' same United country middle shadow South White Middle West city Midwest US U suburbs North world southern midst mountains northern heart Philippines East Pacific state UK western nation shadows woods New eastern past Northern Caribbean Capitol San Netherlands " Bronx small south Bay Washington Bahamas inner area Democratic most far Central Soviet Great very American Northeast center capital west present house north upper Southern \' home Dominican fictional vicinity dark'

# %%
print("Edited Tokens")
topk_token_vals_edit, topk_token_preds_edit = torch.topk(patched_logits, 70)
gpt2_small.to_string(topk_token_preds_edit[0][-1])
# Out:
# Edited Tokens
# ' United White same country South shadow middle West city Middle U North heart Midwest US nation southern world suburbs midst Philippines northern Oval East state Pacific Democratic New mountains western Washington San capital Capitol " Northern eastern south past shadows Bay UK small Black most woods Caribbean American District Central Republican Soviet Netherlands far area west inner north home president Bahamas Southern center Bronx house Trump northeast Northeast former very'

# %% [markdown]
# # How do we edit the memories at each head?
#
# We can inject concepts into the residual stream by editing the outputs of individual attention heads.
#
# (SIDE NOTE: In reality this is the same thing as editing the entire output of an attention layer since all attention head outputs are added together before being added back into the residual stream. We still decided to include this section for illustrative purposes.)
#
# **How do we do this:**
#
# We project memories from vocabulary space into the pseudo-latent space of the model by applying the transpose of the unembedding matrix to the tokenized memory. We then add these transformed memories directly to the outputs of a specific attention head.
#
# ![picture](https://drive.google.com/uc?export=view&id=11PXMPvywR_ZtQNLM615-KB7ltfc0yivM)

# %%
# This function does not do anything different from "memory_tweaker_hook"
# All the outputs of all attention heads in each layer are added together before
# being added back into the residual stream of the model

#Args:
def memory_tweaker_head_hook(
    attn_result: Float[torch.Tensor, "num_tokens num_heads d_model"],
    hook: HookPoint, #name of layer where we inject memory
    extra_info: str, #the string that we tokenize and then inject into memory
    model: transformer_lens.HookedTransformer, #the model from which we get the unembedding matrix from
    vocab_size: int, #size of model vocabulary
    tweak_factor: float,
    head_num: int #The number of the head we want to edit
    #cache: transformer_lens.ActivationCache #this is the
) -> Float[torch.Tensor, "batch pos d_model"]:



    #print("Hook point: ", hook.name)
    #print("head num: ", head_num)
    #tokenize string
    tok_extra_info = model.to_tokens(extra_info, prepend_bos=False)
    #print(tok_extra_info)

    #transform tokens into one-hot vector
    #TODO: switch back to zeros
    extra_memory = torch.zeros(vocab_size).to(device)
    #extra_memory = torch.ones(vocab_size)
    #TODO: need to put a one in the spot with all of the extra info tokens and mult by tweak factor
    for i in tok_extra_info:
      extra_memory[i] = 1

    #subtract bias, and apply transpose of unembeding matrix to tokenized string to get it into model's hidden dim
    #extra_memory = extra_memory - model.unembed.b_U
    extra_memory = einsum("d_vocab, d_vocab d_model-> d_model", extra_memory, model.W_U.T)

    #TODO think about how layer norm would imapct things

    #add the extra_info embedded in latent space to hook_attn_out
    #print(attn_result.shape)
    attn_result[:,:,head_num,:] = attn_result[:,:,head_num,:] + extra_memory * tweak_factor
    #attn_result[:,:,head_num,:] + extra_memory * tweak_factor
    #print(attn_result[:,:,head_num,:])

    # TODO: Add a "jiggle" feature here.

    #return this edited hook_attn_out
    return attn_result

# %% [markdown]
# Below, simply edit the prompt, extra_info, head_number, tweak_factor, layer to adjust to your example.

# %%
# Use functools.partial to create a temporary hook function with the position fixed
temp_hook_fn = partial(memory_tweaker_head_hook,
                       extra_info="The president",
                       vocab_size=50257,
                       model=gpt2_small,
                       tweak_factor=3,
                       head_num=0)



prompt = "The leader of the United States lives in the"
#Get original logits
logits = gpt2_small(prompt)

#Get patched Logits
layer  = 9
patched_logits = gpt2_small.run_with_hooks(prompt,
                          fwd_hooks=[
                                      ( utils.get_act_name("result", layer),
                                      temp_hook_fn)
                                      ]
                          )

# %%
print("Unedited top K tokens: ")
topk_token_vals, topk_token_preds = torch.topk(logits, 70)
gpt2_small.to_string(topk_token_preds[0][-1])
# Out:
# Unedited top K tokens:
# ' same United country middle shadow South White Middle West city Midwest US U suburbs North world southern midst mountains northern heart Philippines East Pacific state UK western nation shadows woods New eastern past Northern Caribbean Capitol San Netherlands " Bronx small south Bay Washington Bahamas inner area Democratic most far Central Soviet Great very American Northeast center capital west present house north upper Southern \' home Dominican fictional vicinity dark'

# %%
print("Edited top K tokens: ")
topk_token_vals_edit, topk_token_preds_edit = torch.topk(patched_logits, 70)
gpt2_small.to_string(topk_token_preds_edit[0][-1])
# Out:
# Edited top K tokens:
# ' United White same country South shadow middle West city Middle U North heart Midwest US nation southern world suburbs midst Philippines northern Oval East state Pacific Democratic New mountains western Washington San capital Capitol " Northern eastern south past shadows Bay UK small Black most woods Caribbean American District Central Republican Soviet Netherlands far area west inner north home president Bahamas Southern center Bronx house Trump northeast Northeast former very'

# %%
def apply_edit(model, extra_memory, prompt, tweak_factor=4, layer=10, head_num=0 ):
  # Use functools.partial to create a temporary hook function with the position fixed
  temp_hook_fn = partial(memory_tweaker_head_hook,
                        extra_info= extra_memory, #"Barak Obama",
                        vocab_size=50257,
                        model=model,
                        tweak_factor=tweak_factor,
                        head_num=head_num)


  #prompt = "The first black president of the United States was a member of the"
  #Get original logits
  logits = model(prompt)

  #Get patched Logits
  layer  = layer
  patched_logits = model.run_with_hooks(prompt,
                            fwd_hooks=[
                                        ( utils.get_act_name("result", layer),
                                        temp_hook_fn)
                                        ]
                            )
  return logits, patched_logits

# %%
def interpret_logits_as_vocab(model, logits, top_k=30):
  topk_token_vals_edit, topk_token_preds_edit = torch.topk(logits, top_k)
  return model.to_string(topk_token_preds_edit[0][-1])

# %%
logits, patched_logits = apply_edit(gpt2_large, "Abe Lincoln",
                                    "George Washington fought in the",
                                    tweak_factor=4, layer=9, head_num=8)
print("original logits")
print(interpret_logits_as_vocab(gpt2_large, logits))
print("edited logits")
print(interpret_logits_as_vocab(gpt2_large, patched_logits))
# Out:
# original logits
#  Revolutionary American Civil War war Revolution French Battle Continental Spanish Mexican first battle Virginia First Indian U British battles Second Crimean wars bloody Great famous Seven great Union North United
# edited logits
#  Revolutionary American War Civil war French Revolution Battle Continental Spanish Mexican first Virginia wars U battle British First Indian Second Great battles Crimean bloody United Union North famous Seven revolutionary

# %%
logits, patched_logits = apply_edit(gpt2_large, "George Washington",
                                    "The first president of the United States fought in the",
                                    tweak_factor=4, layer=9, head_num=5)
print("original logits")
print(interpret_logits_as_vocab(gpt2_large, logits))
print("edited logits")
print(interpret_logits_as_vocab(gpt2_large, patched_logits))
# Out:
# original logits
#  Civil Revolutionary American Spanish Mexican war War Battle trenches French Vietnam Second First Philippines Great Philippine Korean Revolution civil first bloody Crimean wars World European blood battle United Indian U
# edited logits
#  Civil Revolutionary American Spanish war Mexican War trenches Battle Philippines French Vietnam First Second Philippine Great first Revolution Crimean wars civil bloody Korean European United World blood Union Pacific U

# %%
logits, patched_logits = apply_edit(gpt2_large, "George Washington",
                                    "The first president of the United States fought in the",
                                    tweak_factor=4, layer=9, head_num=7)
print("original logits")
print(interpret_logits_as_vocab(gpt2_large, logits))
print("edited logits")
print(interpret_logits_as_vocab(gpt2_large, patched_logits))
# Out:
# original logits
#  Civil Revolutionary American Spanish Mexican war War Battle trenches French Vietnam Second First Philippines Great Philippine Korean Revolution civil first bloody Crimean wars World European blood battle United Indian U
# edited logits
#  Civil Revolutionary American Spanish war Mexican War trenches Battle Philippines French Vietnam First Second Philippine Great first Revolution Crimean wars civil bloody Korean European United World blood Union Pacific U

# %% [markdown]
# # Helper Functions

# %%
'''
    Function to compute the probability of the next token (ans) completion
    given the logits or prompt. Either prompt or logits needs to be passed.
'''
def get_ans_prob(model, ans, prompt=None, logits=None):
    if logits is None and prompt is None:
        raise ValueError("Either logits or prompt needs to be provided")
    ans_token = model.to_tokens(ans)[0][1]
    if logits is None:
        tokens = model.to_tokens(prompt)
        logits, cache = model.run_with_cache(tokens, remove_batch_dim=True)

    total_ans_prob = torch.nn.functional.softmax(logits, -1)[0][-1][ans_token].item()
    return total_ans_prob

# %%
def prompt_model(prompt, model, k_tokens=10):
  logits = model(prompt)
  vals, idx = torch.topk(logits, k_tokens)
  return model.to_string(idx[0][-1])

# %%
prompt_model("The first black president of the United States is a member of the", gpt2_small)
#The name of the largest coral reef is the
# Out:
# ' Ku African House United U KKK National Council Supreme Senate'

# %% [markdown]
# #Get Data
#
# We use a handwritten dataset and a programatically generated dataset. We felt it was important to handwrite one of our datasets to ensure factual/gramatical accuracy.
#
# **Dataset format:** There is one sentence with an explicit entitiy, and another sentence with an "obscure" entity. The "obscure" entity requires 1 hop of reasoning to resolve. See examples below.
#
# Please see our paper for additional specifics: https://arxiv.org/abs/2309.05605

# %%
#Download and load data from git repo (this is the handwritten dataset)
url="https://raw.githubusercontent.com/msakarvadia/memory_injections/main/data/handwritten_obscure_explicit_data.csv"
s=requests.get(url).content
data=pd.read_csv(io.StringIO(s.decode('utf-8')))

#Drop empty rows
data = data[data['answer'] != ""]

#Prepend " " (space) to each answer
for i in range(len(data['answer'])):
  data['answer'][i] = ' '+ data['answer'][i]

data
# Out:
#                                explicit_sentence  \
# 0                George Washington fought in the
# 1                     The president lives in the
# 2         St. Peter's Basilica is in the city of
# 3                              Jesus died on the
# 4       Elephants are the largest land mammal on
# ..                                           ...
# 101  The Louvre Museum is located in the city of
# 102              Mount Everest is located in the
# 103                   Mammoth Cave is located in
# 104                          The blue whale is a
# 105   Jupiter is the largest planet in the solar
#
#                                       obscure_sentence       explicit_entity  \
# 0    The first president of the United States fough...     George Washington
# 1         The leader of the United States lives in the         The president
# 2    The biggest church in the world is in the city of  St. Peter's Basilica
# 3                           The son of God died on the                 Jesus
# 4    Animals with long trunks are the largest land ...             Elephants
# ..                                                 ...                   ...
# 101  The largest art museum in the world is located...     The Louvre Museum
# 102    The highest peak in the world is located in the         Mount Everest
# 103       The longest known cave system is located in           Mammoth Cave
# 104                   The largest animal to exist is a            blue whale
# 105  The fifth planet from the sun is the largest p...               Jupiter
#
#                                obscure_entity              answer
# 0    The first president of the United States   Revolutionary War
# 1             The leader of the United States         White House
# 2             The biggest church in the world                Rome
# 3                              The son of God               cross
# 4                    Animals with long trunks               Earth
# ..                                        ...                 ...
# 101       The largest art museum in the world               Paris
# 102             The highest peak in the world           Himalayan
# 103             The longest known cave system            Kentucky
# 104                   largest animal to exist              mammal
# 105             The fifth planet from the sun              system
#
# [106 rows x 5 columns]

# %%
#Download and load data from git repo (this is the handwritten dataset)
url="https://raw.githubusercontent.com/msakarvadia/memory_injections/main/data/multi_hop_1000.csv"
s=requests.get(url).content
multi=pd.read_csv(io.StringIO(s.decode('utf-8')))

multi = multi.drop([ 'fact1', 'fact2'], axis=1)

#Need to add a " " space to the front of every answer to account for funny tokenization
for i in range(len(multi['answer'])):
  multi['answer'][i] = ' '+ multi['answer'][i]

multi.rename(columns={"explicit_sent": "explicit_sentence", "obscure_sent": "obscure_sentence"}, inplace=True)

multi
# Out:
# <ipython-input-28-aadfa8ee13ee>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multi['answer'][i] = ' '+ multi['answer'][i]
#      Unnamed: 0                                  explicit_sentence  \
# 0             0       The country of citizenship of Jaap Speyer is
# 1             1               The place of birth of Dušan Hanák is
# 2             2             The place of death of James Vincent is
# 3             3              The place of birth of Emil Loteanu is
# 4             4  The country of citizenship of Archduke Karl Sa...
# ..          ...                                                ...
# 995         995                             The spouse of Fredi is
# 996         996       The place of death of Gianfranco Parolini is
# 997         997  The date of death of Francis Baring, 3rd Baron...
# 998         998          The place of birth of Eleanor de Clare is
# 999         999                 The place of death of Abdülaziz is
#
#                                       obscure_sentence  \
# 0    The country of citizenship of the director of ...
# 1    The place of birth of the director of I Love, ...
# 2    The place of death of the director of Gold and...
# 3    The place of birth of the director of Lăutarii is
# 4    The country of citizenship of the father of Ar...
# ..                                                 ...
# 995        The spouse of the performer of Pump-Pump is
# 996  The place of death of the director of Francis ...
# 997  The date of death of the father of Alexander H...
# 998  The place of birth of the mother of Edward le ...
# 999  The place of death of the father of Şehzade Yu...
#
#                          explicit_entity  \
# 0                            Jaap Speyer
# 1                            Dušan Hanák
# 2                          James Vincent
# 3                           Emil Loteanu
# 4      Archduke Karl Salvator of Austria
# ..                                   ...
# 995                                Fredi
# 996                  Gianfranco Parolini
# 997  Francis Baring, 3rd Baron Ashburton
# 998                     Eleanor de Clare
# 999                            Abdülaziz
#
#                                         obscure_entity                answer
# 0                     the director of Lilli's Marriage                 Dutch
# 1                     the director of I Love, You Love            Bratislava
# 2                   the director of Gold and the Woman              New York
# 3                             the director of Lăutarii               Romania
# 4    the father of Archduke Leopold Salvator of Aus...               Italian
# ..                                                 ...                   ...
# 995                         the performer of Pump-Pump   Eva-Riitta Siitonen
# 996               the director of Francis the Smuggler                  Rome
# 997  the father of Alexander Hugh Baring, 4th Baron...      6 September 1868
# 998                  the mother of Edward le Despenser            Caerphilly
# 999               the father of Şehzade Yusuf Izzeddin        Constantinople
#
# [1000 rows x 6 columns]

# %% [markdown]
# # How useful is memory editing at a specific head (if we know what to inject)
#
# The working **hypothesis** here is the: the obscure (multi-hop) prompts are lacking specific memories (the additional hop) which is why their completions are not as good as explicit prompt completions.
#
# We have a dataset of obscure prompts, explicit prompts, and respectively their obscure subject and explicit subject.
#
# We wonder if injecting the explicit subject as a memory into the obscure prompts hidden activation states will be enough to correct the final prompt.
#
# We will **measure** this memory injection approach's success by counting how much the individual probability of the desired next token increases.

# %%
def print_edit_results(data, model, layer=9, head_num=8, tweak_factor=4):
  average_answer_prob_change_after_edit = 0
  data['ans_prob_obs'] = 0
  data['ans_prob_exp'] = 0
  data['ans_prob_after_edit'] = 0

  for i in range(len(data['answer'])):
    answer = data['answer'][i]
    memory = data['explicit_entity'][i]
    prompt = data['obscure_sentence'][i]

    explicit_prompt = data['explicit_sentence'][i]
    exp_logits = model(explicit_prompt)


    logits, patched_logits = apply_edit(model,
                                      memory,
                                      prompt,
                                      tweak_factor=tweak_factor,
                                      layer=layer,
                                      head_num=head_num)

    first_answer_tok = gpt2_small.to_tokens(answer, prepend_bos=False)[0][0].item()
    answer_prob_before_mem = torch.nn.functional.softmax(logits[0][-1], dim=0)[first_answer_tok]
    answer_prob_after_mem = torch.nn.functional.softmax(patched_logits[0][-1], dim=0)[first_answer_tok]
    ans_prob_exp = torch.nn.functional.softmax(exp_logits[0][-1], dim=0)[first_answer_tok]

    average_answer_prob_change_after_edit += answer_prob_after_mem - answer_prob_before_mem

    data.loc[i, 'ans_prob_obs'] = answer_prob_before_mem.item()
    data.loc[i, 'ans_prob_exp'] = ans_prob_exp.item()
    data.loc[i, 'ans_prob_after_edit'] = answer_prob_after_mem.item()

    print("Prompt: ", prompt)
    print("Answer: ", data['answer'][i])
    print("Memory: ", memory)
    print("original logits | Answer Probability: ", answer_prob_before_mem)
    print(interpret_logits_as_vocab(model, logits))
    print("edited logits| Answer Probability: ", answer_prob_after_mem)
    print(interpret_logits_as_vocab(model, patched_logits))
    print("---------------- ", i)
  print("Average Answer probability difference after edit: ", average_answer_prob_change_after_edit/len(data['answer']))
  return data

# %%
diffs = print_edit_results(data, gpt2_small)
# Out:
# Prompt:  The first president of the United States fought in the
# Answer:   Revolutionary War
# Memory:  George Washington
# original logits | Answer Probability:  tensor(0.0670)
#  Vietnam Civil Korean Revolutionary Battle Spanish Second war World Great Mexican Philippines First South Pacific Indian American Iraq Persian Cuban civil Philippine War first French Middle Crimean second wars Cold
# edited logits| Answer Probability:  tensor(0.0596)
#  Vietnam Civil Revolutionary Korean World war Battle South Great Spanish Philippines Iraq War George Second Mexican Pacific Persian Gulf wars North civil American Cuban first Middle Cold First Philippine 18
# ----------------  0
# Prompt:  The leader of the United States lives in the
# Answer:   White House
# Memory:  The president
# original logits | Answer Probability:  tensor(0.0174)
#  same United country middle shadow South White Middle West city Midwest US U suburbs North world southern midst mountains northern heart Philippines East Pacific state UK western nation shadows woods
# edited logits| Answer Probability:  tensor(0.0940)
#  White United same country South shadow West middle city Middle U heart North nation Oval Midwest world US southern suburbs Philippines East midst northern state president Democratic New Pacific capital
# ----------------  1
# Prompt:  The biggest church in the world is in the city of
# Answer:   Rome
# Memory:  St. Peter's Basilica
# original logits | Answer Probability:  tensor(0.0372)
#  Rome Jerusalem San St New Buenos London Alexandria Los Cologne Tokyo Antioch Paris Barcelona T Toronto B K L Florence Chicago Manila D Seattle Bethlehem Milan Athens Nice P Orlando
# edited logits| Answer Probability:  tensor(0.0961)
#  St Rome Jerusalem New Saint Basil San Peter London Milan Buenos Florence Alexandria S T Pal B Paul Antioch L Paris Al Santa P Geneva Z Amsterdam Naples Salt Nic
# ----------------  2
# Prompt:  The son of God died on the
# Answer:   cross
# Memory:  Jesus
# original logits | Answer Probability:  tensor(0.1187)
#  cross day eve battlefield third way spot same night road seventh 10 altar second morning scene Sabbath eighth 9 first 12 7 5 fourth 3 8 sixth fifth mountain 6
# edited logits| Answer Probability:  tensor(0.3431)
#  cross eve third day way battlefield road spot altar same seventh Cross 10 second Sabbath night 12 eighth scene mountain 13 sixth morning fourth 9 6 first 5 15 19
# ----------------  3
# Prompt:  Animals with long trunks are the largest land mammal on
# Answer:   Earth
# Memory:  Elephants
# original logits | Answer Probability:  tensor(0.4732)
#  Earth earth the land Mars our this planet a record North all Planet human any mainland average every U both New an American Venus humans Mount America Australia Antarctica campus
# edited logits| Answer Probability:  tensor(0.3105)
#  the Earth earth land Mars this planet our record a all North mainland Planet average every Australia Antarctica any America an U Mount New both VenusshoreEarth Lake Africa
# ----------------  4
# Prompt:  The first black president of the United States was a member of the
# Answer:   Senate
# Memory:  Barack Obama
# original logits | Answer Probability:  tensor(0.0139)
#  Ku KKK African House Confederate United U National Supreme Senate military Confederacy NAACP Democratic first Black Republican black First Communist Council American British " South armed Klan Continental white New
# edited logits| Answer Probability:  tensor(0.0135)
#  Obama Ku African Republican House Democratic KKK Supreme United U National Senate Bush Black " Confederate First Confederacy American first White NAACP Clinton black Cuban Kennedy military Council Jewish Muslim
# ----------------  5
# Prompt:  The tallest building in the world is located in the city of
# Answer:   Dubai
# Memory:  Burj Khalifa
# original logits | Answer Probability:  tensor(0.0068)
#  Tokyo New San Beijing B T K L Z Los S P St Shanghai D London G Barcelona Hong N Tian Paris Dubai Berlin Buenos M Istanbul Rome Pal Abu
# edited logits| Answer Probability:  tensor(0.0446)
#  Dubai Abu K J D B N San Kh Al Z S T Ar Bur New P Dh L Q Las G Jerusalem Qatar Dur Los Bas Cairo Gu Sh
# ----------------  6
# Prompt:  The oldest civilization originated in the modern-day country of
# Answer:   Iraq
# Memory:  Mesopotamian civilization
# original logits | Answer Probability:  tensor(0.0067)
#  China India the Egypt South Ethiopia Mes Israel Kazakhstan Mexico Mongolia North Africa Afghanistan Iran Tibet Peru Madagascar Japan Greece Pakistan Cambodia Papua Brazil Iraq Turkey Indonesia Spain Central New
# edited logits| Answer Probability:  tensor(0.0077)
#  Mes India Sumopot Chinaes Egypt Israelo the Mexico Asia Man Iran Greece Iraq Ar New Am Africa Ind Peru Ethiopia Japanam, Mongoliaus Ae
# ----------------  7
# Prompt:  The famous Pastor and Civil Rights leader delivered the speech during the March on Washington in 1963 widely known as I Had A
# Answer:   Dream
# Memory:  Martin Luther King Jr.
# original logits | Answer Probability:  tensor(0.2727)
#  Dream Gay Little Good Plan Word Wonderful Baby Merry Choice Prayer Son Moment Child Great Voice Revolution Hard Heart Message Straight White Better Right Lot Black President Woman Question Gun
# edited logits| Answer Probability:  tensor(0.0176)
#  Luther King Martin Little Son Dream Hard Christmas Good Baptist Lot Million Gay Plan Black President Loving. Kennedy Merry Boy White Negro Job Lamb Vision Man Prayer God Father
# ----------------  8
# Prompt:  The largest toothed whale dives deep into the ocean to hunt giant
# Answer:   squid
# Memory:  The sperm whale
# original logits | Answer Probability:  tensor(0.1208)
#  whales squid sea killer fish whale sharks seals e blue mammals dolphins hump, black sperm c white b prey ot marine p creatures wh crust animals tuna jelly birds
# edited logits| Answer Probability:  tensor(0.0368)
#  whales sperm whale squid sea killer fish sharks hump e seals, blue black c dolphins white b wh mammals p marine m jelly s ot fin rays salmon tuna
# ----------------  9
# Prompt:  The surface of the densest planet in the Solar System is mostly covered in
# Answer:   water
# Memory:  The surface of the Earth
# original logits | Answer Probability:  tensor(0.0414)
#  ice dust dense a water liquid clouds gas the thick methane dark rocky icy black carbon rock tiny extremely oceans hydrogen thin an rocks snow sand small red massive layers
# edited logits| Answer Probability:  tensor(0.0835)
#  the ice a water surface dust Earth liquid dense rocky gas clouds rock an dark carbon black rocks oceans thick icy thin solid methane layers small stars land tiny hydrogen
# ----------------  10
# Prompt:  The first spanish explorer to land in the Americas' expedition led to the
# Answer:   discovery
# Memory:  Columbus' expedition
# original logits | Answer Probability:  tensor(0.4426)
#  discovery first creation arrival establishment formation capture development conclusion release publication return opening world idea colonization founding destruction birth construction conquest recognition emergence realization most settlement beginning death arrest island
# edited logits| Answer Probability:  tensor(0.6141)
#  discovery first arrival expedition creation formation return development colonization establishment opening settlement capture publication release emergence death world destruction largest construction founding eventual exploration conquest landing conclusion idea most '
# ----------------  11
# Prompt:  The first champion of the UFC was born in the country of
# Answer:   Brazil
# Memory:  Royce Gracie
# original logits | Answer Probability:  tensor(0.0464)
#  his Brazil the Japan Mexico Ireland France Colombia New Thailand China South England Romania Cameroon America Canada Italy Sweden their Australia Germany Bangladesh Afghanistan Denmark Argentina Hawaii Laos Puerto California
# edited logits| Answer Probability:  tensor(0.0411)
#  Grac Brazil Englandie his Mexico South the Japan Roy France New Romania Georgia Jamaica America Ireland Colombia Canada Guce Cameroon Rio Texas Belgium Italy Ce Spain Argentina Germany
# ----------------  12
# Prompt:  Henry Ford's competitor was a lover of the sport of
# Answer:   racing
# Memory:  Enzo Ferrari
# original logits | Answer Probability:  tensor(0.0526)
#  racing road golf track the speed sports motorcycle driving football motor drag horse street mot baseball car hockey Formula boxing pickup cycling running soft sport race aer automobile basketball tennis
# edited logits| Answer Probability:  tensor(0.0401)
#  Formula Ferrari racing speed road street motorcycle mot golf the sports motor drag football Ford track F horse Speed motors pickup fast race car sport tennis mar baseball driving Jaguar
# ----------------  13
# Prompt:  The bear flag state is the most
# Answer:   populous
# Memory:  California
# original logits | Answer Probability:  tensor(0.0074)
#  popular common important commonly prominent widely recognizable famous powerful visible significant recent beautiful iconic well populous obvious frequently diverse recognized likely flag basic interesting familiar successful controversial ancient prevalent dominant
# edited logits| Answer Probability:  tensor(0.0163)
#  common popular important prominent commonly widely famous recent populous visible powerful recognizable significant iconic diverse well beautiful obvious frequently recognized successful likely controversial familiar dangerous prevalent basic extreme difficult heavily
# ----------------  14
# Prompt:  The golden bear state is the most
# Answer:   populous
# Memory:  California
# original logits | Answer Probability:  tensor(0.0574)
#  populous popular important beautiful dangerous common diverse abundant densely fertile famous powerful populated nort prominent significant widely interesting endangered difficult biologically prolific heavily stable active visited peaceful ancient well likely
# edited logits| Answer Probability:  tensor(0.0915)
#  populous popular important diverse beautiful dangerous common nort abundant famous densely fertile powerful endangered widely populated significant prominent prolific heavily extreme difficult interesting well biologically remote commonly expensive likely desirable
# ----------------  15
# Prompt:  Bill Clinton's wife was a candidate for
# Answer:   president
# Memory:  Hillary Clinton
# original logits | Answer Probability:  tensor(0.3325)
#  president the governor President secretary a Congress U mayor vice US attorney Senate Arkansas state office New Secretary both federal public his an Governor Florida her senator Virginia lieutenant California
# edited logits| Answer Probability:  tensor(0.3090)
#  president the President secretary a governor vice U Congress Senate Hillary Secretary Clinton his both her New US Arkansas Democratic attorney mayor Florida office Vice Virginia senator Obama an California
# ----------------  16
# Prompt:  The man who coined the term Hawking Radiation worked in the field of
# Answer:   quantum
# Memory:  Stephen Hawking
# original logits | Answer Probability:  tensor(0.0640)
#  radiation physics quantum nuclear astroph radio astronomy biology space electromagnetic bio molecular cos cancer genetics artificial bi chemistry medicine particle the climate radioactive computer biological nan optics " medical theoretical
# edited logits| Answer Probability:  tensor(0.1094)
#  quantum Hawking astroph physics radiation nuclear astronomy biology radio cos molecular cancer genetics artificial the space bi computer chemistry bio medicine electromagnetic theoretical Physics " super Quantum climate relativity particle
# ----------------  17
# Prompt:  The Argentine forward for Barcelona is a champion in the game of
# Answer:   football
# Memory:  Lionel Messi
# original logits | Answer Probability:  tensor(0.3617)
#  football soccer basketball the tennis his chess hockey rugby Spanish attacking drib goal sports ball baseball international life " a passing making defense volleyball professional possession defence shooting catching cricket
# edited logits| Answer Probability:  tensor(0.2672)
#  football Messi the soccer basketballel his a Barcelona Lionel Spanish " La chess passing life tennis Luis hockey ball rugby sports goal baseball la magic play possession their cricket
# ----------------  18
# Prompt:  Bill Gates' company created the operating system for
# Answer:   Windows
# Memory:  Microsoft
# original logits | Answer Probability:  tensor(0.0687)
#  the Microsoft Windows a Google Apple Android smartphones mobile its Facebook Xbox computers Minecraft Linux an NASA IBM Amazon virtual PCs operating computer many Internet computing all iOS every Bitcoin
# edited logits| Answer Probability:  tensor(0.1199)
#  Microsoft Windows the Apple Google a Xbox Android Facebook Linux smartphones Intel Amazon Minecraft IBM mobile its an iOS PCs computers Nintendo Sony Internet virtual NASA operating Firefox many Oracle
# ----------------  19
# Prompt:  Agent 007 works for the
# Answer:   British
# Memory:  James Bond
# original logits | Answer Probability:  tensor(0.0029)
#  CIA FBI United government US U NSA same White DEA New Federal military Empire X Department Black Avengers company Red KGB D S Government Russian Pentagon Justice team " British
# edited logits| Answer Probability:  tensor(0.0080)
#  FBI CIA United US government NSA U British James Bond Federal same New X White Department KGB Government Agency Black Avengers S Justice DEA Royal D Russian American Red Agents
# ----------------  20
# Prompt:  The father of computer science devised a way to break the ciphers made from the machine called the
# Answer:   enigma
# Memory:  Alan Turing
# original logits | Answer Probability:  tensor(0.0002)
#  " C ' R Turing H P S Open computer D Internet AES N X F Big Crypto quantum Cipher SHA L B c z Z Intel RSA K T
# edited logits| Answer Probability:  tensor(8.1146e-06)
#  Turing " C ' R H P Big Open X quantum computer D S Go T BAS N F Forth SHA Deep B Random Hilbert L Shannon Watson Super A
# ----------------  21
# Prompt:  Steve Jobs' successor oversaw the introduction of the Apple
# Answer:   Watch
# Memory:  Tim Cook
# original logits | Answer Probability:  tensor(0.4048)
#  Watch II TV iPhone logo computer Pay Computer i operating watch iPad I mobileCare Macintosh Pen Store desktop platform iPod brand App A ][ Mac- PC 3 television
# edited logits| Answer Probability:  tensor(0.6340)
#  Watch II TVCare iPhone Pay Store iPad Computer Cook operating i Tim logo watch Pen App I Maps iPod computer MacScript Genius ][ Stores Music Research desktop Way
# ----------------  22
# Prompt:  The King of Pop released the best-selling album of all time which is named
# Answer:   Thriller
# Memory:  Michael Jackson
# original logits | Answer Probability:  tensor(0.0002)
#  " after ' the for The in as by Best one, No with to # After King a on Billboard and Top Pop Album Prince best among following P
# edited logits| Answer Probability:  tensor(0.0002)
#  " ' after the The Michael for in by as Best James, No Billboard John King Eminem Prince Jackson After David # and one Jack George Top with to
# ----------------  23
# Prompt:  The Windy City is where the World's Columbian Exposition took place in the year of
# Answer:   1893
# Memory:  Chicago
# original logits | Answer Probability:  tensor(0.0194)
#  the 18 Columb 1912 1893 1996 1999 1911 its 1995 1896 2000 1906 1993 1945 17 1914 2001 1994 1997 1998 World 1937 1933 1900 1898 1907 1899 1901 1992
# edited logits| Answer Probability:  tensor(0.0462)
#  18 the 1893 1896 1912 1906 Columb 1911 1907 1996 17 1908 1900 1995 1898 1993 its 1999 1904 1919 1933 1929 1994 1897 1936 1909 1945 1901 2000 1937
# ----------------  24
# Prompt:  The architect of the reign of terror executed many of his ideological opponents during the
# Answer:   French Revolution
# Memory:  Robespierre
# original logits | Answer Probability:  tensor(0.0056)
#  reign Second war second 20 last first revolution Holocaust period 19 Arab Cold 1930 Syrian early years Middle Soviet late 1980 Muslim Ottoman civil bloody 1920 First campaign 1960 Islamic
# edited logits| Answer Probability:  tensor(0.0055)
#  reign Second revolution Revolution second 20 19 first war last Crus First early 1980 Arab years period Thirty campaign Spanish civil 18 9 time 15 1960 17 1930 Middle French
# ----------------  25
# Prompt:  The big country near New Zealand has a jumping marsupial animal called a
# Answer:   Kangaroo
# Memory:  Australia
# original logits | Answer Probability:  tensor(0.0004)
#  " k ' p t le m sp cat Tasman b black l pengu P g d h rh c ch par red hy K T gir z mars man
# edited logits| Answer Probability:  tensor(0.0008)
#  " k ' Tasman p t ko pengu m le cat b sp black ge l par g man giant z h c gir red rh s P n d
# ----------------  26
# Prompt:  The bodybuilding governor of California was born in the country of
# Answer:   Austria
# Memory:  Arnold Schwarzenegger
# original logits | Answer Probability:  tensor(0.0036)
#  his the California Israel Czech Denmark Hawaii Che a China Mexico Puerto Italy Mexican Ghana Japan El Brazil Ecuador Italian American Chinese British Sweden French Salvador South Germany Albania Cameroon
# edited logits| Answer Probability:  tensor(0.0021)
#  Schwarzeneggerold hisAr Ar Arnoldn Argentina the Elhiso Reagan California Czech Israel Arn Lincoln American Denmark South Che New a China Abraham John " Germany Austria
# ----------------  27
# Prompt:  The largest university in the Buckeye State is called The
# Answer:   Ohio State University
# Memory:  Ohio
# original logits | Answer Probability:  tensor(0.1138)
#  University Ohio College Buc Citadel Big School Great Institute State Center New Art Columbus Graduate Holy Bear Oregon Sacred B North Golden John American Mount Michigan National Cincinnati Student City
# edited logits| Answer Probability:  tensor(0.4813)
#  Ohio University Buc College BigOhio Citadel Columbus Great State School Oregon Michigan New Cincinnati Center Institute North Cleveland Holy American Urban Sacred Washington Bear National Summit Art Mount John
# ----------------  28
# Prompt:  Canadians call their $1 coin a "loonie" because this type of winged animal appears on it
# Answer:   Common Loon
# Memory:  bird
# original logits | Answer Probability:  tensor(8.1596e-07)
# 's in., at all every and as more? a on almost when several regularly too like so many only with once to twice often for just frequently
# edited logits| Answer Probability:  tensor(1.4261e-06)
# 's in., at all and as? on a every when more too like several almost only many twice regularly once to so with from just often for
# ----------------  29
# Prompt:  The university with the most Nobel Prizes is located in the Chicago neighborhood of
# Answer:   Hyde Park
# Memory:  The University of Chicago
# original logits | Answer Probability:  tensor(0.0084)
#  Chicago West South the Oak W North Lincoln East Lake Highland St Eng Hyde Park Long El O Bel Dear Northwestern Grand University Wood S Mid Rose Cook Glen Garfield
# edited logits| Answer Probability:  tensor(0.0019)
#  Chicago University South West Northwestern North St the Highland W Oak Lincoln Eng East Lake Cook Park El Marqu Illinois New O Du Long Grand Mid Dear Washington Union College
# ----------------  30
# Prompt:  Después de las guerras de independencia hispanoamericanas, el libertador estableció la nación de la
# Answer:   Gran Colombia
# Memory:  Simon Bolivar
# original logits | Answer Probability:  tensor(0.0002)
#  n de liber histor c p v m rec se com su s gu pr fam f soc conf g est econom t l tr lib reg comp h N
# edited logits| Answer Probability:  tensor(0.0003)
#  n v de pr p l c tr liberar r g se m la t f lib ch com gu histor j s los econom rec soc suiv
# ----------------  31
# Prompt:  The founder of Microsoft was born in the city of
# Answer:   Seattle
# Memory:  Bill Gates
# original logits | Answer Probability:  tensor(0.0155)
#  Redmond Cambridge Detroit Seattle New Boston Los St San Baltimore Bangalore K Bellev London Kiev Chicago Berlin Shanghai Beijing B L Z Moscow Palo T S Helsinki Hyder Sydney Washington
#  the being his what death a getting losing going her becoming having him spoilers dragons " making giving dying it taking Tolkien an this leaving how God heights coming seeing
# edited logits| Answer Probability:  tensor(0.0005)
#  Tolkien the being his what a her him death getting it having this going dragons losing J. " Gand that God an, all making my doing becoming dying
# ----------------  38
# Prompt:  The U.S.'s first national laboratory conducted pioneering research on
# Answer:   nuclear energy
# Memory:  Argonne National Laboratory
# original logits | Answer Probability:  tensor(0.0022)
#  the how a human stem cancer brain this its animal an DNA genetic drug gene genetically HIV micro " protein what cell bacteria mice early microbial nan drugs bacterial blood
# edited logits| Answer Probability:  tensor(0.0013)
#  the a human how Laboratory  " brain early DNA this and an cell e ne l ar its d micro b animal t laboratory r k cancer Ne gl
# ----------------  39
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-d1d4ecc37685> in <cell line: 1>()
# ----> 1 diffs = print_edit_results(data, gpt2_small)
#
# <ipython-input-29-6f2ff5ec619e> in print_edit_results(data, model, layer, head_num, tweak_factor)
#      11
#      12     explicit_prompt = data['explicit_sentence'][i]
# ---> 13     exp_logits = model(explicit_prompt)
#      14
#      15
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformer_lens/HookedTransformer.py in forward(self, input, return_type, loss_per_token, prepend_bos, padding_side, start_at_layer, tokens, shortformer_pos_embed, left_attention_mask, stop_at_layer, past_kv_cache, past_left_attention_mask)
#     478                     )
#     479
# --> 480                 residual = block(
#     481                     residual,
#     482                     past_kv_cache_entry=past_kv_cache[i]
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformer_lens/components.py in forward(self, resid_pre, shortformer_pos_embed, past_kv_cache_entry, left_attention_mask)
#    1041             # queries, keys and values, independently.
#    1042             # Then take the layer norm of these inputs, and pass these to the attention module.
# -> 1043             self.attn(
#    1044                 query_input=self.ln1(query_input)
#    1045                 + (0.0 if shortformer_pos_embed is None else shortformer_pos_embed),
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformer_lens/components.py in forward(self, query_input, key_input, value_input, past_kv_cache_entry, additive_attention_mask, left_attention_mask)
#     548
#     549         q = self.hook_q(
# --> 550             einsum(
#     551                 f"{qkv_einops_string}, head_index d_model d_head \
#     552                 -> batch pos head_index d_head",
#
# /usr/local/lib/python3.10/dist-packages/fancy_einsum/__init__.py in einsum(equation, *operands)
#     134     backend = get_backend(operands[0])
#     135     new_equation = convert_equation(equation)
# --> 136     return backend.einsum(new_equation, *operands)
#
# /usr/local/lib/python3.10/dist-packages/fancy_einsum/__init__.py in einsum(self, equation, *operands)
#      52
#      53     def einsum(self, equation, *operands):
# ---> 54         return self.torch.einsum(equation, *operands)
#      55
#      56
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py in einsum(*args)
#     376         # the path for contracting 0 or 1 time(s) is already optimized
#     377         # or the user has disabled using opt_einsum
# --> 378         return _VF.einsum(equation, operands)  # type: ignore[attr-defined]
#     379
#     380     path = None
#
# KeyboardInterrupt:

# %% [markdown]
# # Citation
#
# Please cite this work as:
#
#
#
# ```
# @article{sakarvadia2023memory,
#   title={Memory Injections: Correcting Multi-Hop Reasoning Failures during Inference in Transformer-Based Language Models},
#   author={Sakarvadia, Mansi and Ajith, Aswathy and Khan, Arham and Grzenda, Daniel and Hudson, Nathaniel and Bauer, Andr{\'e} and Chard, Kyle and Foster, Ian},
#   journal={arXiv preprint arXiv:2309.05605},
#   year={2023}
# }
# ```
